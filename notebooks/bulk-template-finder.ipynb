# %%
from pathlib import Path
import json
import os
from pprint import pprint
from rdflib import RDF, Graph, Namespace
from collections import defaultdict
from typing import List, Set, Dict
from buildingmotif import BuildingMOTIF
from buildingmotif.dataclasses import Library, Template
from buildingmotif.template_finder.template_finder import calculate_best_bindings_for_template_and_tokens
from buildingmotif.template_finder.classes import LabelSet, SegmentedLabel, Param, Token, BestLabelSetBindings

from datetime import datetime as dt
from dataclasses import dataclass

BLDG = Namespace("urn:building/")
PROJECT_DIR = Path(os.getcwd()).resolve().parent

# %%
bm = BuildingMOTIF("sqlite://")

Library.load(ontology_graph="https://github.com/BrickSchema/Brick/releases/download/nightly/Brick.ttl")
ground_truth = Library.load(ontology_graph=str(PROJECT_DIR / "gabes_points" / "sprucehall.ttl"))
equiment_templates = Library.load(directory=str(PROJECT_DIR / "gabes_points" / "equiment_templates"))

templates = equiment_templates.get_templates()
# Out:
# 2023-10-04 13:27:08,332 | root |  WARNING: Warning: could not find dependee https://brickschema.org/schema/Brick/ref#ifcProject
# 2023-10-04 13:27:08,332 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7045
# 2023-10-04 13:27:08,333 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7047
# 2023-10-04 13:27:08,333 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7049
# 2023-10-04 13:27:08,333 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7051
# 2023-10-04 13:27:08,333 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7053
# 2023-10-04 13:27:08,334 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6972
# 2023-10-04 13:27:08,334 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6974
# 2023-10-04 13:27:08,334 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6976
# 2023-10-04 13:27:08,334 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6978
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6980
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7011
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7013
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7015
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7017
# 2023-10-04 13:27:08,335 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb7019
# 2023-10-04 13:27:08,336 | root |  WARNING: Warning: could not find dependee http://data.ashrae.org/bacnet/2020#BACnetDevice
# 2023-10-04 13:27:08,336 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6922
# 2023-10-04 13:27:08,336 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6924
# 2023-10-04 13:27:08,336 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6926
# 2023-10-04 13:27:08,336 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6928
# 2023-10-04 13:27:08,337 | root |  WARNING: Warning: could not find dependee n547a01f730484919a69060941df2212cb6930

# %%
with open(PROJECT_DIR / "gabes_points" / "tokens.json") as f:
    labels_and_tokens = json.load(f)

# %%
# LabelSets are a set SegmentedLabels with shared token_classes. This cell builds that. 
labelsets: List[LabelSet] = []

for label_and_tokens in labels_and_tokens:
    label = label_and_tokens["label"]
    tokens = sorted(label_and_tokens["tokens"], key=lambda x: x["type"])
    token_classes = [t['type'] for t in tokens]
    token_identifiers = [t['identifier'] for t in tokens]

    # SegmentedLabel for label
    segmented_label = SegmentedLabel(
        label=label,
        identifiers=token_identifiers
    )

    # proper labelset for SegmentedLabel
    labelset = next((
        labelset for labelset in labelsets 
        if labelset.token_classes == token_classes
    ), None)
    if labelset is None:
        labelset = LabelSet(token_classes=token_classes, segmented_labels=[])
        labelsets.append(labelset)

    # append it to the label set
    labelset.segmented_labels.append(segmented_label)


# print
for labelset in labelsets:
    print(f"{len(labelset.segmented_labels)} labels with token classes:")
    pprint(labelset.token_classes)
# Out:
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Chilled_Water_Valve',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 1373 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupancy_Status']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint']
# 199 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint']
# 1078 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Air_Temperature_Sensor',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 272 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Hot_Water_Valve']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor']
# 258 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint']
# 270 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupancy_Command']

# %%
# get the best bindings for each labelset. 
# The binding's param's identifiers are the index of the labelset.segmented_labels[].identifiers
# so that the bindings can be applied to every labelset.segmented_labels
best_labelset_bindings_list = []
for labelset in labelsets:
    print(f"token classes: {labelset.token_classes}")
    print(labelset.segmented_labels[0])
    print()

    index_tokens = [
        Token(identifier=i, classname=tc) 
        for i, tc in enumerate(labelset.token_classes)
    ]
    best_template, best_bindings, _ = calculate_best_bindings_for_template_and_tokens(templates, index_tokens, verbose=True)
    best_labelset_bindings_list.append(BestLabelSetBindings(
        template=best_template,
        labelset=labelset,
        bindings_indices=best_bindings
    ))

    print(f"\nBest Template: {best_template.name}")
    print(f"bindings_indices: {best_bindings}")
    print("\n-----------------------------")
# Out:
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Chilled_Water_Valve', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# SegmentedLabel(label=':BuildingName_02:FCU503_ChwVlvPos', identifiers=['02', ':BuildingName_02:FCU503_ChwVlvPos', 'BuildingName', '503'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Chilled_Water_Valve Entity  \
# Supply_Air_Temperature_Sensor               inf                 inf    inf
# Fan_Coil_Unit                               inf                 inf    inf
#
#                               Fan_Coil_Unit
# Supply_Air_Temperature_Sensor           inf
# Fan_Coil_Unit                             0
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Chilled_Water_Valve  \
# Fan_Coil_Unit                                         inf                 inf
# HVAC_Zone                                             inf                 inf
# Occupied_Heating_Temperature_Setpoint                 inf                 inf
# Occupied_Cooling_Temperature_Setpoint                 inf                 inf
# Occupancy_Command                                     inf                 inf
# Supply_Air_Temperature_Sensor                         inf                 inf
# Unoccupied_Cooling_Temperature_Setpoint               inf                 inf
# Occupancy_Status                                      inf                 inf
# Unoccupied_Heating_Temperature_Setpoint               inf                 inf
# Space                                                 inf                 inf
# Relative_Humidity_Sensor                              inf                 inf
# Air_Temperature_Sensor                                inf                 inf
# Hot_Water_Valve                                       inf                 inf
# Heating_Coil                                          inf                 inf
# Valve_Position_Command                                inf                 inf
# Valve_Position_Command                                inf                 inf
# Cooling_Coil                                          inf                 inf
# Chilled_Water_Valve                                   inf                   0
#
#                                         Entity Fan_Coil_Unit
# Fan_Coil_Unit                              inf             0
# HVAC_Zone                                  inf           inf
# Occupied_Heating_Temperature_Setpoint      inf           inf
# Occupied_Cooling_Temperature_Setpoint      inf           inf
# Occupancy_Command                          inf           inf
# Supply_Air_Temperature_Sensor              inf           inf
# Unoccupied_Cooling_Temperature_Setpoint    inf           inf
# Occupancy_Status                           inf           inf
# Unoccupied_Heating_Temperature_Setpoint    inf           inf
# Space                                      inf           inf
# Relative_Humidity_Sensor                   inf           inf
# Air_Temperature_Sensor                     inf           inf
# Hot_Water_Valve                            inf           inf
# Heating_Coil                               inf           inf
# Valve_Position_Command                     inf           inf
# Valve_Position_Command                     inf           inf
# Cooling_Coil                               inf           inf
# Chilled_Water_Valve                        inf           inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Chilled_Water_Valve <- 0.0 -> Chilled_Water_Valve
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Chilled_Water_Valve Entity  \
# Space                                  inf                 inf    inf
# Relative_Humidity_Sensor               inf                 inf    inf
# Air_Temperature_Sensor                 inf                 inf    inf
#
#                          Fan_Coil_Unit
# Space                              inf
# Relative_Humidity_Sensor           inf
# Air_Temperature_Sensor             inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Chilled_Water_Valve Entity  \
# Heating_Coil                         inf                 inf    inf
# Hot_Water_Valve                      inf                 inf    inf
# Valve_Position_Command               inf                 inf    inf
#
#                        Fan_Coil_Unit
# Heating_Coil                     inf
# Hot_Water_Valve                  inf
# Valve_Position_Command           inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Chilled_Water_Valve Entity  \
# Cooling_Coil                         inf                 inf    inf
# Chilled_Water_Valve                  inf                   0    inf
# Valve_Position_Command               inf                 inf    inf
#
#                        Fan_Coil_Unit
# Cooling_Coil                     inf
# Chilled_Water_Valve              inf
# Valve_Position_Command           inf
#
# kept edges:
# Chilled_Water_Valve <- 0.0 -> Chilled_Water_Valve
# - cooling_coil 3.0
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: 1 a Chilled_Water_Valve}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# SegmentedLabel(label=':BuildingName_01:FCU336_OccHtgSptFnl', identifiers=['01', 'BuildingName', 'OccHtgSptFnl', '336'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Entity Fan_Coil_Unit
# Supply_Air_Temperature_Sensor               inf    inf    inf           inf
# Fan_Coil_Unit                               inf    inf    inf             0
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity Entity  \
# Fan_Coil_Unit                                         inf    inf    inf
# HVAC_Zone                                             inf    inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf    inf
# Occupancy_Command                                     inf    inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf    inf
# Occupancy_Status                                      inf    inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf    inf
# Space                                                 inf    inf    inf
# Relative_Humidity_Sensor                              inf    inf    inf
# Air_Temperature_Sensor                                inf    inf    inf
# Hot_Water_Valve                                       inf    inf    inf
# Heating_Coil                                          inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Cooling_Coil                                          inf    inf    inf
# Chilled_Water_Valve                                   inf    inf    inf
#
#                                         Fan_Coil_Unit
# Fan_Coil_Unit                                       0
# HVAC_Zone                                         inf
# Occupied_Heating_Temperature_Setpoint             inf
# Occupied_Cooling_Temperature_Setpoint             inf
# Occupancy_Command                                 inf
# Supply_Air_Temperature_Sensor                     inf
# Unoccupied_Cooling_Temperature_Setpoint           inf
# Occupancy_Status                                  inf
# Unoccupied_Heating_Temperature_Setpoint           inf
# Space                                             inf
# Relative_Humidity_Sensor                          inf
# Air_Temperature_Sensor                            inf
# Hot_Water_Valve                                   inf
# Heating_Coil                                      inf
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - fcu 3.0
# cost matrix:
#                          Air_Handling_Unit Entity Entity Fan_Coil_Unit
# Space                                  inf    inf    inf           inf
# Relative_Humidity_Sensor               inf    inf    inf           inf
# Air_Temperature_Sensor                 inf    inf    inf           inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Fan_Coil_Unit
# Heating_Coil                         inf    inf    inf           inf
# Hot_Water_Valve                      inf    inf    inf           inf
# Valve_Position_Command               inf    inf    inf           inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Fan_Coil_Unit
# Cooling_Coil                         inf    inf    inf           inf
# Chilled_Water_Valve                  inf    inf    inf           inf
# Valve_Position_Command               inf    inf    inf           inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupancy_Status']
# SegmentedLabel(label=':BuildingName_02:FCU510_EffOcc', identifiers=['02', 'BuildingName', '510', ':BuildingName_02:FCU510_EffOcc'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Occupancy_Status
# Supply_Air_Temperature_Sensor              inf
# Fan_Coil_Unit                              inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit Occupancy_Status
# Fan_Coil_Unit                                       0              inf
# HVAC_Zone                                         inf              inf
# Occupied_Heating_Temperature_Setpoint             inf              inf
# Occupied_Cooling_Temperature_Setpoint             inf              inf
# Occupancy_Command                                 inf              inf
# Supply_Air_Temperature_Sensor                     inf              inf
# Unoccupied_Cooling_Temperature_Setpoint           inf              inf
# Occupancy_Status                                  inf                0
# Unoccupied_Heating_Temperature_Setpoint           inf              inf
# Space                                             inf              inf
# Relative_Humidity_Sensor                          inf              inf
# Air_Temperature_Sensor                            inf              inf
# Hot_Water_Valve                                   inf              inf
# Heating_Coil                                      inf              inf
# Valve_Position_Command                            inf              inf
# Valve_Position_Command                            inf              inf
# Cooling_Coil                                      inf              inf
# Chilled_Water_Valve                               inf              inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Occupancy_Status <- 0.0 -> Occupancy_Status
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Occupancy_Status
# Space                                 inf
# Relative_Humidity_Sensor              inf
# Air_Temperature_Sensor                inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit Occupancy_Status
# Heating_Coil                         inf    inf           inf              inf
# Hot_Water_Valve                      inf    inf           inf              inf
# Valve_Position_Command               inf    inf           inf              inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit Occupancy_Status
# Cooling_Coil                         inf    inf           inf              inf
# Chilled_Water_Valve                  inf    inf           inf              inf
# Valve_Position_Command               inf    inf           inf              inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, occ_status a Occupancy_Status: 3 a Occupancy_Status}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint']
# SegmentedLabel(label=':BuildingName_02:FCU507_UnoccHtgSpt', identifiers=['02', 'BuildingName', '507', ':BuildingName_02:FCU507_UnoccHtgSpt'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Unoccupied_Heating_Temperature_Setpoint
# Supply_Air_Temperature_Sensor                                     inf
# Fan_Coil_Unit                                                     inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit  \
# Fan_Coil_Unit                                       0
# HVAC_Zone                                         inf
# Occupied_Heating_Temperature_Setpoint             inf
# Occupied_Cooling_Temperature_Setpoint             inf
# Occupancy_Command                                 inf
# Supply_Air_Temperature_Sensor                     inf
# Unoccupied_Cooling_Temperature_Setpoint           inf
# Occupancy_Status                                  inf
# Unoccupied_Heating_Temperature_Setpoint           inf
# Space                                             inf
# Relative_Humidity_Sensor                          inf
# Air_Temperature_Sensor                            inf
# Hot_Water_Valve                                   inf
# Heating_Coil                                      inf
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
#                                         Unoccupied_Heating_Temperature_Setpoint
# Fan_Coil_Unit                                                               inf
# HVAC_Zone                                                                   inf
# Occupied_Heating_Temperature_Setpoint                                       inf
# Occupied_Cooling_Temperature_Setpoint                                       inf
# Occupancy_Command                                                           inf
# Supply_Air_Temperature_Sensor                                               inf
# Unoccupied_Cooling_Temperature_Setpoint                                     inf
# Occupancy_Status                                                            inf
# Unoccupied_Heating_Temperature_Setpoint                                       0
# Space                                                                       inf
# Relative_Humidity_Sensor                                                    inf
# Air_Temperature_Sensor                                                      inf
# Hot_Water_Valve                                                             inf
# Heating_Coil                                                                inf
# Valve_Position_Command                                                      inf
# Valve_Position_Command                                                      inf
# Cooling_Coil                                                                inf
# Chilled_Water_Valve                                                         inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Unoccupied_Heating_Temperature_Setpoint <- 0.0 -> Unoccupied_Heating_Temperature_Setpoint
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Unoccupied_Heating_Temperature_Setpoint
# Space                                                        inf
# Relative_Humidity_Sensor                                     inf
# Air_Temperature_Sensor                                       inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Heating_Coil                         inf    inf           inf
# Hot_Water_Valve                      inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Unoccupied_Heating_Temperature_Setpoint
# Heating_Coil                                               inf
# Hot_Water_Valve                                            inf
# Valve_Position_Command                                     inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Cooling_Coil                         inf    inf           inf
# Chilled_Water_Valve                  inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Unoccupied_Heating_Temperature_Setpoint
# Cooling_Coil                                               inf
# Chilled_Water_Valve                                        inf
# Valve_Position_Command                                     inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, unocc_htg_sp a Unoccupied_Heating_Temperature_Setpoint: 3 a Unoccupied_Heating_Temperature_Setpoint}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint']
# SegmentedLabel(label=':BuildingName_01:FCU203_OccClgSpt', identifiers=['01', 'BuildingName', '203', ':BuildingName_01:FCU203_OccClgSpt'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Occupied_Cooling_Temperature_Setpoint
# Supply_Air_Temperature_Sensor                                   inf
# Fan_Coil_Unit                                                   inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit  \
# Fan_Coil_Unit                                       0
# HVAC_Zone                                         inf
# Occupied_Heating_Temperature_Setpoint             inf
# Occupied_Cooling_Temperature_Setpoint             inf
# Occupancy_Command                                 inf
# Supply_Air_Temperature_Sensor                     inf
# Unoccupied_Cooling_Temperature_Setpoint           inf
# Occupancy_Status                                  inf
# Unoccupied_Heating_Temperature_Setpoint           inf
# Space                                             inf
# Relative_Humidity_Sensor                          inf
# Air_Temperature_Sensor                            inf
# Hot_Water_Valve                                   inf
# Heating_Coil                                      inf
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
#                                         Occupied_Cooling_Temperature_Setpoint
# Fan_Coil_Unit                                                             inf
# HVAC_Zone                                                                 inf
# Occupied_Heating_Temperature_Setpoint                                     inf
# Occupied_Cooling_Temperature_Setpoint                                       0
# Occupancy_Command                                                         inf
# Supply_Air_Temperature_Sensor                                             inf
# Unoccupied_Cooling_Temperature_Setpoint                                   inf
# Occupancy_Status                                                          inf
# Unoccupied_Heating_Temperature_Setpoint                                   inf
# Space                                                                     inf
# Relative_Humidity_Sensor                                                  inf
# Air_Temperature_Sensor                                                    inf
# Hot_Water_Valve                                                           inf
# Heating_Coil                                                              inf
# Valve_Position_Command                                                    inf
# Valve_Position_Command                                                    inf
# Cooling_Coil                                                              inf
# Chilled_Water_Valve                                                       inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Occupied_Cooling_Temperature_Setpoint <- 0.0 -> Occupied_Cooling_Temperature_Setpoint
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Occupied_Cooling_Temperature_Setpoint
# Space                                                      inf
# Relative_Humidity_Sensor                                   inf
# Air_Temperature_Sensor                                     inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Heating_Coil                         inf    inf           inf
# Hot_Water_Valve                      inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupied_Cooling_Temperature_Setpoint
# Heating_Coil                                             inf
# Hot_Water_Valve                                          inf
# Valve_Position_Command                                   inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Cooling_Coil                         inf    inf           inf
# Chilled_Water_Valve                  inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupied_Cooling_Temperature_Setpoint
# Cooling_Coil                                             inf
# Chilled_Water_Valve                                      inf
# Valve_Position_Command                                   inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, occ_clg_sp a Occupied_Cooling_Temperature_Setpoint: 3 a Occupied_Cooling_Temperature_Setpoint}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# SegmentedLabel(label=':BuildingName_02:FCU521_UO11_HwVlvOut', identifiers=['02', 'BuildingName', '11', 'HwVlvOut', '521'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Entity Entity  \
# Supply_Air_Temperature_Sensor               inf    inf    inf    inf
# Fan_Coil_Unit                               inf    inf    inf    inf
#
#                               Fan_Coil_Unit
# Supply_Air_Temperature_Sensor           inf
# Fan_Coil_Unit                             0
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 4.0
# cost matrix:
#                                         Air_Handling_Unit Entity Entity  \
# Fan_Coil_Unit                                         inf    inf    inf
# HVAC_Zone                                             inf    inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf    inf
# Occupancy_Command                                     inf    inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf    inf
# Occupancy_Status                                      inf    inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf    inf
# Space                                                 inf    inf    inf
# Relative_Humidity_Sensor                              inf    inf    inf
# Air_Temperature_Sensor                                inf    inf    inf
# Hot_Water_Valve                                       inf    inf    inf
# Heating_Coil                                          inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Cooling_Coil                                          inf    inf    inf
# Chilled_Water_Valve                                   inf    inf    inf
#
#                                         Entity Fan_Coil_Unit
# Fan_Coil_Unit                              inf             0
# HVAC_Zone                                  inf           inf
# Occupied_Heating_Temperature_Setpoint      inf           inf
# Occupied_Cooling_Temperature_Setpoint      inf           inf
# Occupancy_Command                          inf           inf
# Supply_Air_Temperature_Sensor              inf           inf
# Unoccupied_Cooling_Temperature_Setpoint    inf           inf
# Occupancy_Status                           inf           inf
# Unoccupied_Heating_Temperature_Setpoint    inf           inf
# Space                                      inf           inf
# Relative_Humidity_Sensor                   inf           inf
# Air_Temperature_Sensor                     inf           inf
# Hot_Water_Valve                            inf           inf
# Heating_Coil                               inf           inf
# Valve_Position_Command                     inf           inf
# Valve_Position_Command                     inf           inf
# Cooling_Coil                               inf           inf
# Chilled_Water_Valve                        inf           inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - fcu 4.0
# cost matrix:
#                          Air_Handling_Unit Entity Entity Entity Fan_Coil_Unit
# Space                                  inf    inf    inf    inf           inf
# Relative_Humidity_Sensor               inf    inf    inf    inf           inf
# Air_Temperature_Sensor                 inf    inf    inf    inf           inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Entity Fan_Coil_Unit
# Heating_Coil                         inf    inf    inf    inf           inf
# Hot_Water_Valve                      inf    inf    inf    inf           inf
# Valve_Position_Command               inf    inf    inf    inf           inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Entity Fan_Coil_Unit
# Cooling_Coil                         inf    inf    inf    inf           inf
# Chilled_Water_Valve                  inf    inf    inf    inf           inf
# Valve_Position_Command               inf    inf    inf    inf           inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 4 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Air_Temperature_Sensor', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# SegmentedLabel(label=':BuildingName_02:FCU416_RoomTmp', identifiers=['02', ':BuildingName_02:FCU416_RoomTmp', 'BuildingName', '416'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Air_Temperature_Sensor Entity  \
# Supply_Air_Temperature_Sensor               inf                    inf    inf
# Fan_Coil_Unit                               inf                    inf    inf
#
#                               Fan_Coil_Unit
# Supply_Air_Temperature_Sensor           inf
# Fan_Coil_Unit                             0
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit  \
# Fan_Coil_Unit                                         inf
# HVAC_Zone                                             inf
# Occupied_Heating_Temperature_Setpoint                 inf
# Occupied_Cooling_Temperature_Setpoint                 inf
# Occupancy_Command                                     inf
# Supply_Air_Temperature_Sensor                         inf
# Unoccupied_Cooling_Temperature_Setpoint               inf
# Occupancy_Status                                      inf
# Unoccupied_Heating_Temperature_Setpoint               inf
# Space                                                 inf
# Relative_Humidity_Sensor                              inf
# Air_Temperature_Sensor                                inf
# Hot_Water_Valve                                       inf
# Heating_Coil                                          inf
# Valve_Position_Command                                inf
# Valve_Position_Command                                inf
# Cooling_Coil                                          inf
# Chilled_Water_Valve                                   inf
#
#                                         Air_Temperature_Sensor Entity  \
# Fan_Coil_Unit                                              inf    inf
# HVAC_Zone                                                  inf    inf
# Occupied_Heating_Temperature_Setpoint                      inf    inf
# Occupied_Cooling_Temperature_Setpoint                      inf    inf
# Occupancy_Command                                          inf    inf
# Supply_Air_Temperature_Sensor                              inf    inf
# Unoccupied_Cooling_Temperature_Setpoint                    inf    inf
# Occupancy_Status                                           inf    inf
# Unoccupied_Heating_Temperature_Setpoint                    inf    inf
# Space                                                      inf    inf
# Relative_Humidity_Sensor                                   inf    inf
# Air_Temperature_Sensor                                       0    inf
# Hot_Water_Valve                                            inf    inf
# Heating_Coil                                               inf    inf
# Valve_Position_Command                                     inf    inf
# Valve_Position_Command                                     inf    inf
# Cooling_Coil                                               inf    inf
# Chilled_Water_Valve                                        inf    inf
#
#                                         Fan_Coil_Unit
# Fan_Coil_Unit                                       0
# HVAC_Zone                                         inf
# Occupied_Heating_Temperature_Setpoint             inf
# Occupied_Cooling_Temperature_Setpoint             inf
# Occupancy_Command                                 inf
# Supply_Air_Temperature_Sensor                     inf
# Unoccupied_Cooling_Temperature_Setpoint           inf
# Occupancy_Status                                  inf
# Unoccupied_Heating_Temperature_Setpoint           inf
# Space                                             inf
# Relative_Humidity_Sensor                          inf
# Air_Temperature_Sensor                            inf
# Hot_Water_Valve                                   inf
# Heating_Coil                                      inf
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Air_Temperature_Sensor <- 0.0 -> Air_Temperature_Sensor
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Air_Temperature_Sensor Entity  \
# Space                                  inf                    inf    inf
# Relative_Humidity_Sensor               inf                    inf    inf
# Air_Temperature_Sensor                 inf                      0    inf
#
#                          Fan_Coil_Unit
# Space                              inf
# Relative_Humidity_Sensor           inf
# Air_Temperature_Sensor             inf
#
# kept edges:
# Air_Temperature_Sensor <- 0.0 -> Air_Temperature_Sensor
# - room 3.0
# cost matrix:
#                        Air_Handling_Unit Air_Temperature_Sensor Entity  \
# Heating_Coil                         inf                    inf    inf
# Hot_Water_Valve                      inf                    inf    inf
# Valve_Position_Command               inf                    inf    inf
#
#                        Fan_Coil_Unit
# Heating_Coil                     inf
# Hot_Water_Valve                  inf
# Valve_Position_Command           inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Air_Temperature_Sensor Entity  \
# Cooling_Coil                         inf                    inf    inf
# Chilled_Water_Valve                  inf                    inf    inf
# Valve_Position_Command               inf                    inf    inf
#
#                        Fan_Coil_Unit
# Cooling_Coil                     inf
# Chilled_Water_Valve              inf
# Valve_Position_Command           inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit, room-temp a Air_Temperature_Sensor: 1 a Air_Temperature_Sensor}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# SegmentedLabel(label=':BuildingName_02:FCU415_UI17_Fan_Status', identifiers=['02', 'BuildingName', '17', 'Fan', 'Status', '415'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Entity Entity Entity  \
# Supply_Air_Temperature_Sensor               inf    inf    inf    inf    inf
# Fan_Coil_Unit                               inf    inf    inf    inf    inf
#
#                               Fan_Coil_Unit
# Supply_Air_Temperature_Sensor           inf
# Fan_Coil_Unit                             0
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 5.0
# cost matrix:
#                                         Air_Handling_Unit Entity Entity  \
# Fan_Coil_Unit                                         inf    inf    inf
# HVAC_Zone                                             inf    inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf    inf
# Occupancy_Command                                     inf    inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf    inf
# Occupancy_Status                                      inf    inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf    inf
# Space                                                 inf    inf    inf
# Relative_Humidity_Sensor                              inf    inf    inf
# Air_Temperature_Sensor                                inf    inf    inf
# Hot_Water_Valve                                       inf    inf    inf
# Heating_Coil                                          inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Valve_Position_Command                                inf    inf    inf
# Cooling_Coil                                          inf    inf    inf
# Chilled_Water_Valve                                   inf    inf    inf
#
#                                         Entity Entity Fan_Coil_Unit
# Fan_Coil_Unit                              inf    inf             0
# HVAC_Zone                                  inf    inf           inf
# Occupied_Heating_Temperature_Setpoint      inf    inf           inf
# Occupied_Cooling_Temperature_Setpoint      inf    inf           inf
# Occupancy_Command                          inf    inf           inf
# Supply_Air_Temperature_Sensor              inf    inf           inf
# Unoccupied_Cooling_Temperature_Setpoint    inf    inf           inf
# Occupancy_Status                           inf    inf           inf
# Unoccupied_Heating_Temperature_Setpoint    inf    inf           inf
# Space                                      inf    inf           inf
# Relative_Humidity_Sensor                   inf    inf           inf
# Air_Temperature_Sensor                     inf    inf           inf
# Hot_Water_Valve                            inf    inf           inf
# Heating_Coil                               inf    inf           inf
# Valve_Position_Command                     inf    inf           inf
# Valve_Position_Command                     inf    inf           inf
# Cooling_Coil                               inf    inf           inf
# Chilled_Water_Valve                        inf    inf           inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - fcu 5.0
# cost matrix:
#                          Air_Handling_Unit Entity Entity Entity Entity  \
# Space                                  inf    inf    inf    inf    inf
# Relative_Humidity_Sensor               inf    inf    inf    inf    inf
# Air_Temperature_Sensor                 inf    inf    inf    inf    inf
#
#                          Fan_Coil_Unit
# Space                              inf
# Relative_Humidity_Sensor           inf
# Air_Temperature_Sensor             inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Entity Entity  \
# Heating_Coil                         inf    inf    inf    inf    inf
# Hot_Water_Valve                      inf    inf    inf    inf    inf
# Valve_Position_Command               inf    inf    inf    inf    inf
#
#                        Fan_Coil_Unit
# Heating_Coil                     inf
# Hot_Water_Valve                  inf
# Valve_Position_Command           inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Entity Entity Entity  \
# Cooling_Coil                         inf    inf    inf    inf    inf
# Chilled_Water_Valve                  inf    inf    inf    inf    inf
# Valve_Position_Command               inf    inf    inf    inf    inf
#
#                        Fan_Coil_Unit
# Cooling_Coil                     inf
# Chilled_Water_Valve              inf
# Valve_Position_Command           inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 5 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Hot_Water_Valve']
# SegmentedLabel(label=':BuildingName_01:FCU391_HwVlvPos', identifiers=['01', 'BuildingName', '391', ':BuildingName_01:FCU391_HwVlvPos'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Hot_Water_Valve
# Supply_Air_Temperature_Sensor             inf
# Fan_Coil_Unit                             inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit Hot_Water_Valve
# Fan_Coil_Unit                                       0             inf
# HVAC_Zone                                         inf             inf
# Occupied_Heating_Temperature_Setpoint             inf             inf
# Occupied_Cooling_Temperature_Setpoint             inf             inf
# Occupancy_Command                                 inf             inf
# Supply_Air_Temperature_Sensor                     inf             inf
# Unoccupied_Cooling_Temperature_Setpoint           inf             inf
# Occupancy_Status                                  inf             inf
# Unoccupied_Heating_Temperature_Setpoint           inf             inf
# Space                                             inf             inf
# Relative_Humidity_Sensor                          inf             inf
# Air_Temperature_Sensor                            inf             inf
# ...
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
#                                         Occupied_Heating_Temperature_Setpoint
# Fan_Coil_Unit                                                             inf
# HVAC_Zone                                                                 inf
# Occupied_Heating_Temperature_Setpoint                                       0
# Occupied_Cooling_Temperature_Setpoint                                     inf
# Occupancy_Command                                                         inf
# Supply_Air_Temperature_Sensor                                             inf
# Unoccupied_Cooling_Temperature_Setpoint                                   inf
# Occupancy_Status                                                          inf
# Unoccupied_Heating_Temperature_Setpoint                                   inf
# Space                                                                     inf
# Relative_Humidity_Sensor                                                  inf
# Air_Temperature_Sensor                                                    inf
# Hot_Water_Valve                                                           inf
# Heating_Coil                                                              inf
# Valve_Position_Command                                                    inf
# Valve_Position_Command                                                    inf
# Cooling_Coil                                                              inf
# Chilled_Water_Valve                                                       inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Occupied_Heating_Temperature_Setpoint <- 0.0 -> Occupied_Heating_Temperature_Setpoint
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Occupied_Heating_Temperature_Setpoint
# Space                                                      inf
# Relative_Humidity_Sensor                                   inf
# Air_Temperature_Sensor                                     inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Heating_Coil                         inf    inf           inf
# Hot_Water_Valve                      inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupied_Heating_Temperature_Setpoint
# Heating_Coil                                             inf
# Hot_Water_Valve                                          inf
# Valve_Position_Command                                   inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Cooling_Coil                         inf    inf           inf
# Chilled_Water_Valve                  inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupied_Heating_Temperature_Setpoint
# Cooling_Coil                                             inf
# Chilled_Water_Valve                                      inf
# Valve_Position_Command                                   inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, occ_htg_sp a Occupied_Heating_Temperature_Setpoint: 3 a Occupied_Heating_Temperature_Setpoint}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint']
# SegmentedLabel(label=':BuildingName_02:FCU489_UnoccClgSpt', identifiers=['02', 'BuildingName', '489', ':BuildingName_02:FCU489_UnoccClgSpt'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Unoccupied_Cooling_Temperature_Setpoint
# Supply_Air_Temperature_Sensor                                     inf
# Fan_Coil_Unit                                                     inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit  \
# Fan_Coil_Unit                                       0
# HVAC_Zone                                         inf
# Occupied_Heating_Temperature_Setpoint             inf
# Occupied_Cooling_Temperature_Setpoint             inf
# Occupancy_Command                                 inf
# Supply_Air_Temperature_Sensor                     inf
# Unoccupied_Cooling_Temperature_Setpoint           inf
# Occupancy_Status                                  inf
# Unoccupied_Heating_Temperature_Setpoint           inf
# Space                                             inf
# Relative_Humidity_Sensor                          inf
# Air_Temperature_Sensor                            inf
# Hot_Water_Valve                                   inf
# Heating_Coil                                      inf
# Valve_Position_Command                            inf
# Valve_Position_Command                            inf
# Cooling_Coil                                      inf
# Chilled_Water_Valve                               inf
#
#                                         Unoccupied_Cooling_Temperature_Setpoint
# Fan_Coil_Unit                                                               inf
# HVAC_Zone                                                                   inf
# Occupied_Heating_Temperature_Setpoint                                       inf
# Occupied_Cooling_Temperature_Setpoint                                       inf
# Occupancy_Command                                                           inf
# Supply_Air_Temperature_Sensor                                               inf
# Unoccupied_Cooling_Temperature_Setpoint                                       0
# Occupancy_Status                                                            inf
# Unoccupied_Heating_Temperature_Setpoint                                     inf
# Space                                                                       inf
# Relative_Humidity_Sensor                                                    inf
# Air_Temperature_Sensor                                                      inf
# Hot_Water_Valve                                                             inf
# Heating_Coil                                                                inf
# Valve_Position_Command                                                      inf
# Valve_Position_Command                                                      inf
# Cooling_Coil                                                                inf
# Chilled_Water_Valve                                                         inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Unoccupied_Cooling_Temperature_Setpoint <- 0.0 -> Unoccupied_Cooling_Temperature_Setpoint
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Unoccupied_Cooling_Temperature_Setpoint
# Space                                                        inf
# Relative_Humidity_Sensor                                     inf
# Air_Temperature_Sensor                                       inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Heating_Coil                         inf    inf           inf
# Hot_Water_Valve                      inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Unoccupied_Cooling_Temperature_Setpoint
# Heating_Coil                                               inf
# Hot_Water_Valve                                            inf
# Valve_Position_Command                                     inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Cooling_Coil                         inf    inf           inf
# Chilled_Water_Valve                  inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Unoccupied_Cooling_Temperature_Setpoint
# Cooling_Coil                                               inf
# Chilled_Water_Valve                                        inf
# Valve_Position_Command                                     inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, unocc_clg_sp a Unoccupied_Cooling_Temperature_Setpoint: 3 a Unoccupied_Cooling_Temperature_Setpoint}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupancy_Command']
# SegmentedLabel(label=':BuildingName_01:FCU223_OccCmd', identifiers=['01', 'BuildingName', '223', ':BuildingName_01:FCU223_OccCmd'])
#
# Template costs:
# cost matrix:
#                               Air_Handling_Unit Entity Fan_Coil_Unit  \
# Supply_Air_Temperature_Sensor               inf    inf           inf
# Fan_Coil_Unit                               inf    inf             0
#
#                               Occupancy_Command
# Supply_Air_Temperature_Sensor               inf
# Fan_Coil_Unit                               inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# - SaTmpEntity 3.0
# cost matrix:
#                                         Air_Handling_Unit Entity  \
# Fan_Coil_Unit                                         inf    inf
# HVAC_Zone                                             inf    inf
# Occupied_Heating_Temperature_Setpoint                 inf    inf
# Occupied_Cooling_Temperature_Setpoint                 inf    inf
# Occupancy_Command                                     inf    inf
# Supply_Air_Temperature_Sensor                         inf    inf
# Unoccupied_Cooling_Temperature_Setpoint               inf    inf
# Occupancy_Status                                      inf    inf
# Unoccupied_Heating_Temperature_Setpoint               inf    inf
# Space                                                 inf    inf
# Relative_Humidity_Sensor                              inf    inf
# Air_Temperature_Sensor                                inf    inf
# Hot_Water_Valve                                       inf    inf
# Heating_Coil                                          inf    inf
# Valve_Position_Command                                inf    inf
# Valve_Position_Command                                inf    inf
# Cooling_Coil                                          inf    inf
# Chilled_Water_Valve                                   inf    inf
#
#                                         Fan_Coil_Unit Occupancy_Command
# Fan_Coil_Unit                                       0               inf
# HVAC_Zone                                         inf               inf
# Occupied_Heating_Temperature_Setpoint             inf               inf
# Occupied_Cooling_Temperature_Setpoint             inf               inf
# Occupancy_Command                                 inf                 0
# Supply_Air_Temperature_Sensor                     inf               inf
# Unoccupied_Cooling_Temperature_Setpoint           inf               inf
# Occupancy_Status                                  inf               inf
# Unoccupied_Heating_Temperature_Setpoint           inf               inf
# Space                                             inf               inf
# Relative_Humidity_Sensor                          inf               inf
# Air_Temperature_Sensor                            inf               inf
# Hot_Water_Valve                                   inf               inf
# Heating_Coil                                      inf               inf
# Valve_Position_Command                            inf               inf
# Valve_Position_Command                            inf               inf
# Cooling_Coil                                      inf               inf
# Chilled_Water_Valve                               inf               inf
#
# kept edges:
# Fan_Coil_Unit <- 0.0 -> Fan_Coil_Unit
# Occupancy_Command <- 0.0 -> Occupancy_Command
# - fcu 2.0
# cost matrix:
#                          Air_Handling_Unit Entity Fan_Coil_Unit  \
# Space                                  inf    inf           inf
# Relative_Humidity_Sensor               inf    inf           inf
# Air_Temperature_Sensor                 inf    inf           inf
#
#                          Occupancy_Command
# Space                                  inf
# Relative_Humidity_Sensor               inf
# Air_Temperature_Sensor                 inf
#
# kept edges:
# - room inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Heating_Coil                         inf    inf           inf
# Hot_Water_Valve                      inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupancy_Command
# Heating_Coil                         inf
# Hot_Water_Valve                      inf
# Valve_Position_Command               inf
#
# kept edges:
# - heating_coil inf
# cost matrix:
#                        Air_Handling_Unit Entity Fan_Coil_Unit  \
# Cooling_Coil                         inf    inf           inf
# Chilled_Water_Valve                  inf    inf           inf
# Valve_Position_Command               inf    inf           inf
#
#                        Occupancy_Command
# Cooling_Coil                         inf
# Chilled_Water_Valve                  inf
# Valve_Position_Command               inf
#
# kept edges:
# - cooling_coil inf
#
# Best Template: fcu
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: 3 a Occupancy_Command}
#
# -----------------------------

# %%
# For each labelset, get the actualized best bindings. 
bindings_by_template_name = defaultdict(list)

for best_labelset_bindings in best_labelset_bindings_list:
    template_name = best_labelset_bindings.template.name
    bindings_list = best_labelset_bindings.get_bindings_list()

    print(f"Binding for {template_name} with token_classes {best_labelset_bindings.labelset.token_classes}")
    for bindings in bindings_list:
        print(f"   - {bindings.segmented_label.label}: {bindings.bindings}")
    
    bindings_by_template_name[template_name] += bindings_list
# Out:
# Binding for fcu with token_classes ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Chilled_Water_Valve', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#    - :BuildingName_02:FCU503_ChwVlvPos: {name a Fan_Coil_Unit: 503 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU503_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU362_ChwVlvPos: {name a Fan_Coil_Unit: 362 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU362_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU343_ChwVlvPos: {name a Fan_Coil_Unit: 343 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU343_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU301_ChwVlvPos: {name a Fan_Coil_Unit: 301 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU301_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU448_ChwVlvPos: {name a Fan_Coil_Unit: 448 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU448_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU530_ChwVlvPos: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU530_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU529_ChwVlvPos: {name a Fan_Coil_Unit: 529 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU529_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU288_ChwVlvPos: {name a Fan_Coil_Unit: 288 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU288_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU313_ChwVlvPos: {name a Fan_Coil_Unit: 313 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU313_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU502_ChwVlvPos: {name a Fan_Coil_Unit: 502 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU502_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU471_ChwVlvPos: {name a Fan_Coil_Unit: 471 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU471_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU252_ChwVlvPos: {name a Fan_Coil_Unit: 252 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU252_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU209_ChwVlvPos: {name a Fan_Coil_Unit: 209 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU209_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU202_ChwVlvPos: {name a Fan_Coil_Unit: 202 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU202_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU442_ChwVlvPos: {name a Fan_Coil_Unit: 442 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU442_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU327_ChwVlvPos: {name a Fan_Coil_Unit: 327 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU327_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU312_ChwVlvPos: {name a Fan_Coil_Unit: 312 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FC
a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU050_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU401_ChwVlvPos: {name a Fan_Coil_Unit: 401 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU401_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU319_ChwVlvPos: {name a Fan_Coil_Unit: 319 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU319_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU356_ChwVlvPos: {name a Fan_Coil_Unit: 356 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU356_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU191_ChwVlvPos: {name a Fan_Coil_Unit: 191 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU191_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU391_ChwVlvPos: {name a Fan_Coil_Unit: 391 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU391_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU276_ChwVlvPos: {name a Fan_Coil_Unit: 276 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU276_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU206_ChwVlvPos: {name a Fan_Coil_Unit: 206 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU206_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU292_ChwVlvPos: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU292_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU309_ChwVlvPos: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU309_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU365_ChwVlvPos: {name a Fan_Coil_Unit: 365 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU365_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU275_ChwVlvPos: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU275_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_01:FCU330_ChwVlvPos: {name a Fan_Coil_Unit: 330 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_01:FCU330_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU444_ChwVlvPos: {name a Fan_Coil_Unit: 444 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU444_ChwVlvPos a Chilled_Water_Valve}
#    - :BuildingName_02:FCU421_ChwVlvPos: {name a Fan_Coil_Unit: 421 a Fan_Coil_Unit, chw_coil-chw_vlv a Chilled_Water_Valve: :BuildingName_02:FCU421_ChwVlvPos a Chilled_Water_Valve}
# ...
#    - :BuildingName_02:FCU558_OccCmd: {name a Fan_Coil_Unit: 558 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU558_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU403_OccCmd: {name a Fan_Coil_Unit: 403 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU403_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU427_OccCmd: {name a Fan_Coil_Unit: 427 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU427_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU527_OccCmd: {name a Fan_Coil_Unit: 527 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU527_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU329_OccCmd: {name a Fan_Coil_Unit: 329 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU329_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU246_OccCmd: {name a Fan_Coil_Unit: 246 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU246_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU325_OccCmd: {name a Fan_Coil_Unit: 325 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU325_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU463_OccCmd: {name a Fan_Coil_Unit: 463 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU463_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU275_OccCmd: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU275_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU502_OccCmd: {name a Fan_Coil_Unit: 502 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU502_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU228_OccCmd: {name a Fan_Coil_Unit: 228 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU228_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU224_OccCmd: {name a Fan_Coil_Unit: 224 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU224_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU271_OccCmd: {name a Fan_Coil_Unit: 271 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU271_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU338_OccCmd: {name a Fan_Coil_Unit: 338 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU338_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU361_OccCmd: {name a Fan_Coil_Unit: 361 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU361_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU210_OccCmd: {name a Fan_Coil_Unit: 210 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU210_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU219_OccCmd: {name a Fan_Coil_Unit: 219 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU219_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU456_OccCmd: {name a Fan_Coil_Unit: 456 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU456_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU354_OccCmd: {name a Fan_Coil_Unit: 354 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU354_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU358_OccCmd: {name a Fan_Coil_Unit: 358 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU358_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU521_OccCmd: {name a Fan_Coil_Unit: 521 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU521_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU559_OccCmd: {name a Fan_Coil_Unit: 559 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU559_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU387_OccCmd: {name a Fan_Coil_Unit: 387 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU387_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU254_OccCmd: {name a Fan_Coil_Unit: 254 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU254_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU515_OccCmd: {name a Fan_Coil_Unit: 515 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU515_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU505_OccCmd: {name a Fan_Coil_Unit: 505 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU505_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU216_OccCmd: {name a Fan_Coil_Unit: 216 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU216_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU324_OccCmd: {name a Fan_Coil_Unit: 324 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU324_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU479_OccCmd: {name a Fan_Coil_Unit: 479 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU479_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU261_OccCmd: {name a Fan_Coil_Unit: 261 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU261_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU543_OccCmd: {name a Fan_Coil_Unit: 543 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU543_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU510_OccCmd: {name a Fan_Coil_Unit: 510 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU510_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU306_OccCmd: {name a Fan_Coil_Unit: 306 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU306_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU538_OccCmd: {name a Fan_Coil_Unit: 538 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU538_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU551_OccCmd: {name a Fan_Coil_Unit: 551 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU551_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU537_OccCmd: {name a Fan_Coil_Unit: 537 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU537_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU221_OccCmd: {name a Fan_Coil_Unit: 221 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU221_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU439_OccCmd: {name a Fan_Coil_Unit: 439 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU439_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU305_OccCmd: {name a Fan_Coil_Unit: 305 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU305_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU531_OccCmd: {name a Fan_Coil_Unit: 531 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU531_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU552_OccCmd: {name a Fan_Coil_Unit: 552 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU552_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU489_OccCmd: {name a Fan_Coil_Unit: 489 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU489_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU303_OccCmd: {name a Fan_Coil_Unit: 303 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU303_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU248_OccCmd: {name a Fan_Coil_Unit: 248 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU248_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU417_OccCmd: {name a Fan_Coil_Unit: 417 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU417_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU373_OccCmd: {name a Fan_Coil_Unit: 373 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU373_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU310_OccCmd: {name a Fan_Coil_Unit: 310 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU310_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU311_OccCmd: {name a Fan_Coil_Unit: 311 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU311_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU482_OccCmd: {name a Fan_Coil_Unit: 482 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU482_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU243_OccCmd: {name a Fan_Coil_Unit: 243 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU243_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU343_OccCmd: {name a Fan_Coil_Unit: 343 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU343_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU406_OccCmd: {name a Fan_Coil_Unit: 406 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU406_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU385_OccCmd: {name a Fan_Coil_Unit: 385 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU385_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU562_OccCmd: {name a Fan_Coil_Unit: 562 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU562_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU307_OccCmd: {name a Fan_Coil_Unit: 307 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU307_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU388_OccCmd: {name a Fan_Coil_Unit: 388 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU388_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU050_OccCmd: {name a Fan_Coil_Unit: 050 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU050_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU473_OccCmd: {name a Fan_Coil_Unit: 473 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU473_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU203_OccCmd: {name a Fan_Coil_Unit: 203 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU203_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU348_OccCmd: {name a Fan_Coil_Unit: 348 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU348_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU265_OccCmd: {name a Fan_Coil_Unit: 265 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU265_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU412_OccCmd: {name a Fan_Coil_Unit: 412 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU412_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU488_OccCmd: {name a Fan_Coil_Unit: 488 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU488_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU485_OccCmd: {name a Fan_Coil_Unit: 485 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU485_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU279_OccCmd: {name a Fan_Coil_Unit: 279 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU279_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU529_OccCmd: {name a Fan_Coil_Unit: 529 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU529_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU294_OccCmd: {name a Fan_Coil_Unit: 294 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU294_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU501_OccCmd: {name a Fan_Coil_Unit: 501 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU501_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU446_OccCmd: {name a Fan_Coil_Unit: 446 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU446_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU364_OccCmd: {name a Fan_Coil_Unit: 364 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU364_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU411_OccCmd: {name a Fan_Coil_Unit: 411 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU411_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU435_OccCmd: {name a Fan_Coil_Unit: 435 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU435_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU407_OccCmd: {name a Fan_Coil_Unit: 407 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU407_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU281_OccCmd: {name a Fan_Coil_Unit: 281 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU281_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU335_OccCmd: {name a Fan_Coil_Unit: 335 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU335_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU356_OccCmd: {name a Fan_Coil_Unit: 356 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU356_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU517_OccCmd: {name a Fan_Coil_Unit: 517 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU517_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU555_OccCmd: {name a Fan_Coil_Unit: 555 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU555_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU528_OccCmd: {name a Fan_Coil_Unit: 528 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU528_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU351_OccCmd: {name a Fan_Coil_Unit: 351 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU351_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU194_OccCmd: {name a Fan_Coil_Unit: 194 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU194_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU360_OccCmd: {name a Fan_Coil_Unit: 360 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU360_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU227_OccCmd: {name a Fan_Coil_Unit: 227 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU227_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU467_OccCmd: {name a Fan_Coil_Unit: 467 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU467_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU516_OccCmd: {name a Fan_Coil_Unit: 516 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU516_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU512_OccCmd: {name a Fan_Coil_Unit: 512 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU512_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU490_OccCmd: {name a Fan_Coil_Unit: 490 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU490_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU530_OccCmd: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU530_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU444_OccCmd: {name a Fan_Coil_Unit: 444 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU444_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU239_OccCmd: {name a Fan_Coil_Unit: 239 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU239_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU204_OccCmd: {name a Fan_Coil_Unit: 204 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU204_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU443_OccCmd: {name a Fan_Coil_Unit: 443 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU443_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU273_OccCmd: {name a Fan_Coil_Unit: 273 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU273_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU217_OccCmd: {name a Fan_Coil_Unit: 217 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU217_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU464_OccCmd: {name a Fan_Coil_Unit: 464 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU464_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU386_OccCmd: {name a Fan_Coil_Unit: 386 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU386_OccCmd a Occupancy_Command}
#    - :BuildingName_02:FCU486_OccCmd: {name a Fan_Coil_Unit: 486 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_02:FCU486_OccCmd a Occupancy_Command}
#    - :BuildingName_01:FCU269_OccCmd: {name a Fan_Coil_Unit: 269 a Fan_Coil_Unit, occ_cmd a Occupancy_Command: :BuildingName_01:FCU269_OccCmd a Occupancy_Command}

# %%
# group the bindings by template, then by the value of the name. 
bindings_by_name_by_template_name = {}
for template_name, bindings_list in bindings_by_template_name.items():
    bindings_by_name = defaultdict(list)
    
    for bindings in bindings_list:
        name = next((
            token.identifier 
            for param, token in bindings.bindings.items()
            if param.name == "name"
        ), None)
        
        bindings_by_name[name].append(bindings)

    bindings_by_name_by_template_name[template_name] = bindings_by_name

for template_name, bindings_by_name in bindings_by_name_by_template_name.items():
    for name, bindings in bindings_by_name.items():
        print(f"{len(bindings)} bindings for {template_name} where name is {name}")
        unified_bindings = {}
        for b in bindings:
            unified_bindings.update(b.bindings)
        print(bindings[0].template)
        args = {p.name: BLDG[t.identifier] for p, t in unified_bindings.items()}
        templ = bindings[0].template.evaluate(args)
        if isinstance(templ, Template):
            _, graph = templ.fill(BLDG)
        else:
            graph = templ
        print(graph.serialize())
        break
# Out:
# 9 bindings for fcu where name is 503
# Template(_id=-1, _name='fcu', body=<Graph identifier=N29c31f6dcdaa454dae9e93776b4d2ab4 (<class 'rdflib.graph.Graph'>)>, optional_args=['unocc_htg_sp', 'occ_clg_sp', 'occ_htg_sp', 'occ_cmd', 'unocc_clg_sp', 'occ_status'], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x128a99850>)
# @prefix brick: <https://brickschema.org/schema/Brick#> .
#
# <urn:building/503> a brick:Fan_Coil_Unit ;
#     brick:feeds <urn:building/zone_cebd7c35> ;
#     brick:hasPart <urn:building/chw_coil_a6f56e14>,
#         <urn:building/hw_coil_6c6c05ae> ;
#     brick:hasPoint <urn:building/:BuildingName_02:FCU503_EffOcc>,
#         <urn:building/:BuildingName_02:FCU503_OccClgSpt>,
#         <urn:building/:BuildingName_02:FCU503_OccCmd>,
#         <urn:building/:BuildingName_02:FCU503_OccHtgSpt>,
#         <urn:building/:BuildingName_02:FCU503_UnoccClgSpt>,
#         <urn:building/:BuildingName_02:FCU503_UnoccHtgSpt>,
#         <urn:building/supply_temp_15396747> .
#
# <urn:building/:BuildingName_02:FCU503_ChwVlvPos> a brick:Chilled_Water_Valve ;
#     brick:hasPoint <urn:building/chw_coil-position_bdf5645a> .
#
# <urn:building/:BuildingName_02:FCU503_EffOcc> a brick:Occupancy_Status .
#
# <urn:building/:BuildingName_02:FCU503_HwVlvPos> a brick:Hot_Water_Valve ;
#     brick:hasPoint <urn:building/hw_coil-position_cc64afd7> .
#
# <urn:building/:BuildingName_02:FCU503_OccClgSpt> a brick:Occupied_Cooling_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU503_OccCmd> a brick:Occupancy_Command .
#
# <urn:building/:BuildingName_02:FCU503_OccHtgSpt> a brick:Occupied_Heating_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU503_RoomTmp> a brick:Air_Temperature_Sensor .
#
# <urn:building/:BuildingName_02:FCU503_UnoccClgSpt> a brick:Unoccupied_Cooling_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU503_UnoccHtgSpt> a brick:Unoccupied_Heating_Temperature_Setpoint .
#
# <urn:building/chw_coil-position_bdf5645a> a brick:Valve_Position_Command .
#
# <urn:building/chw_coil_a6f56e14> a brick:Cooling_Coil ;
#     brick:hasPart <urn:building/:BuildingName_02:FCU503_ChwVlvPos> .
#
# <urn:building/hw_coil-position_cc64afd7> a brick:Valve_Position_Command .
#
# <urn:building/hw_coil_6c6c05ae> a brick:Heating_Coil ;
#     brick:hasPart <urn:building/:BuildingName_02:FCU503_HwVlvPos> .
#
# <urn:building/room-relative_humidity_11f2204a> a brick:Relative_Humidity_Sensor .
#
# <urn:building/room_0e7de8fd> a brick:Space ;
#     brick:hasPoint <urn:building/:BuildingName_02:FCU503_RoomTmp>,
#         <urn:building/room-relative_humidity_11f2204a> .
#
# <urn:building/supply_temp_15396747> a brick:Supply_Air_Temperature_Sensor .
#
# <urn:building/zone_cebd7c35> a brick:HVAC_Zone ;
#     brick:hasPart <urn:building/room_0e7de8fd> .
#
#
# 13 bindings for SaTmpEntity where name is 336
# Template(_id=-1, _name='SaTmpEntity', body=<Graph identifier=N7b673d6ad6484d09996d0f08d59604e2 (<class 'rdflib.graph.Graph'>)>, optional_args=[], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x128a99850>)
# @prefix brick: <https://brickschema.org/schema/Brick#> .
#
# <urn:building/336> a brick:Fan_Coil_Unit ;
#     brick:hasPoint <urn:building/:BuildingName_01:FCU336_UI22_SaTmp> .
#
# <urn:building/:BuildingName_01:FCU336_UI22_SaTmp> a brick:Supply_Air_Temperature_Sensor .

# %%
# example: labels with best bindings on SaTmpEntity where name is "201"
for bindings in bindings_by_name_by_template_name["SaTmpEntity"]["251"]:
    print(bindings.bindings)
# Out:
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {sat a Supply_Air_Temperature_Sensor: :BuildingName_01:FCU251_UI22_SaTmp a Supply_Air_Temperature_Sensor, name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
