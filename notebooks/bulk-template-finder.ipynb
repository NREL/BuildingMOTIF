# %%
from pathlib import Path
import json
import os
from pprint import pprint
from rdflib import RDF, Graph, Namespace
from collections import defaultdict
from typing import List, Set, Dict
from buildingmotif import BuildingMOTIF
from buildingmotif.dataclasses import Library, Template
from buildingmotif.template_finder.template_finder import calculate_best_bindings_for_template_and_tokens
from buildingmotif.template_finder.classes import LabelSet, SegmentedLabel, Param, Token, BestLabelSetBindings

from datetime import datetime as dt
from dataclasses import dataclass

BLDG = Namespace("urn:building/")
PROJECT_DIR = Path(os.getcwd()).resolve().parent

# %%
bm = BuildingMOTIF("sqlite://")

Library.load(ontology_graph="https://github.com/BrickSchema/Brick/releases/download/nightly/Brick.ttl")
ground_truth = Library.load(ontology_graph=str(PROJECT_DIR / "gabes_points" / "sprucehall.ttl"))
equiment_templates = Library.load(directory=str(PROJECT_DIR / "gabes_points" / "equiment_templates"))

templates = equiment_templates.get_templates()
# Out:
# 2023-09-28 12:17:13,032 | root |  WARNING: Warning: could not find dependee http://data.ashrae.org/bacnet/2020#BACnetDevice
# 2023-09-28 12:17:13,050 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7045
# 2023-09-28 12:17:13,051 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7047
# 2023-09-28 12:17:13,052 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7049
# 2023-09-28 12:17:13,053 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7051
# 2023-09-28 12:17:13,054 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7053
# 2023-09-28 12:17:13,055 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6972
# 2023-09-28 12:17:13,056 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6974
# 2023-09-28 12:17:13,057 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6976
# 2023-09-28 12:17:13,058 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6978
# 2023-09-28 12:17:13,059 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6980
# 2023-09-28 12:17:13,060 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6922
# 2023-09-28 12:17:13,060 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6924
# 2023-09-28 12:17:13,061 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6926
# 2023-09-28 12:17:13,062 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6928
# 2023-09-28 12:17:13,063 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b6930
# 2023-09-28 12:17:13,064 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7011
# 2023-09-28 12:17:13,065 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7013
# 2023-09-28 12:17:13,066 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7015
# 2023-09-28 12:17:13,067 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7017
# 2023-09-28 12:17:13,068 | root |  WARNING: Warning: could not find dependee n40c83af7fa5544be801630776ac95304b7019
# 2023-09-28 12:17:13,069 | root |  WARNING: Warning: could not find dependee https://brickschema.org/schema/Brick/ref#ifcProject

# %%
with open(PROJECT_DIR / "gabes_points" / "tokens.json") as f:
    labels_and_tokens = json.load(f)

# %%
# LabelSets are a set SegmentedLabels with shared token_classes. This cell builds that. 
labelsets: List[LabelSet] = []

for label_and_tokens in labels_and_tokens:
    label = label_and_tokens["label"]
    tokens = sorted(label_and_tokens["tokens"], key=lambda x: x["type"])
    token_classes = [t['type'] for t in tokens]
    token_identifiers = [t['identifier'] for t in tokens]

    # SegmentedLabel for label
    segmented_label = SegmentedLabel(
        label=label,
        identifiers=token_identifiers
    )

    # proper labelset for SegmentedLabel
    labelset = next((
        labelset for labelset in labelsets 
        if labelset.token_classes == token_classes
    ), None)
    if labelset is None:
        labelset = LabelSet(token_classes=token_classes, segmented_labels=[])
        labelsets.append(labelset)

    # append it to the label set
    labelset.segmented_labels.append(segmented_label)


# print
for labelset in labelsets:
    print(f"{len(labelset.segmented_labels)} labels with token classes:")
    pprint(labelset.token_classes)
# Out:
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Chilled_Water_Valve',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 1373 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupancy_Status']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint']
# 199 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint']
# 1078 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Air_Temperature_Sensor',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
# 272 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Hot_Water_Valve']
# 273 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor']
# 258 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint']
# 270 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint']
# 259 labels with token classes:
# ['https://brickschema.org/schema/Brick#Air_Handling_Unit',
#  'https://brickschema.org/schema/Brick#Entity',
#  'https://brickschema.org/schema/Brick#Fan_Coil_Unit',
#  'https://brickschema.org/schema/Brick#Occupancy_Command']

# %%
# get the best bindings for each labelset. 
# The binding's param's identifiers are the index of the labelset.segmented_labels[].identifiers
# so that the bindings can be applied to every labelset.segmented_labels
best_labelset_bindings_list = []
for labelset in labelsets:
    print(f"token classes: {labelset.token_classes}")
    print()

    index_tokens = [
        Token(identifier=i, classname=tc) 
        for i, tc in enumerate(labelset.token_classes)
    ]
    best_template, best_bindings, _ = calculate_best_bindings_for_template_and_tokens(templates, index_tokens, verbose=True)
    best_labelset_bindings_list.append(BestLabelSetBindings(
        template=best_template,
        labelset=labelset,
        bindings_indices=best_bindings
    ))

    print(f"\nBest Template: {best_template.name}")
    print(f"bindings_indices: {best_bindings}")
    print("\n-----------------------------")
# Out:
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Chilled_Water_Valve', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil 5.0
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 20.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupancy_Status']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#
# Template costs:
# - SaTmpEntity 5.0
# - fcu 21.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 4 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Air_Temperature_Sensor', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room 5.0
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 3 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#
# Template costs:
# - SaTmpEntity 6.0
# - fcu 22.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 5 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Hot_Water_Valve']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil 5.0
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor']
#
# Template costs:
# - SaTmpEntity 3.0
# - fcu 19.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {sat a Supply_Air_Temperature_Sensor: 4 a Supply_Air_Temperature_Sensor, name a Fan_Coil_Unit: 3 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------
# token classes: ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit', 'https://brickschema.org/schema/Brick#Occupancy_Command']
#
# Template costs:
# - SaTmpEntity 4.0
# - fcu 18.0
# - room inf
# - heating_coil inf
# - cooling_coil inf
#
# Best Template: SaTmpEntity
# bindings_indices: {name a Fan_Coil_Unit: 2 a Fan_Coil_Unit}
#
# -----------------------------

# %%
# For each labelset, get the actualized best bindings. 
bindings_by_template_name = defaultdict(list)

for best_labelset_bindings in best_labelset_bindings_list:
    template_name = best_labelset_bindings.template.name
    bindings_list = best_labelset_bindings.get_bindings_list()

    print(f"Binding for {template_name} with token_classes {best_labelset_bindings.labelset.token_classes}")
    for bindings in bindings_list:
        print(f"   - {bindings.segmented_label.label}: {bindings.bindings}")
    
    bindings_by_template_name[template_name] += bindings_list
# Out:
# Binding for SaTmpEntity with token_classes ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Chilled_Water_Valve', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#    - :BuildingName_02:FCU503_ChwVlvPos: {name a Fan_Coil_Unit: 503 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU362_ChwVlvPos: {name a Fan_Coil_Unit: 362 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU343_ChwVlvPos: {name a Fan_Coil_Unit: 343 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU301_ChwVlvPos: {name a Fan_Coil_Unit: 301 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU448_ChwVlvPos: {name a Fan_Coil_Unit: 448 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU530_ChwVlvPos: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU529_ChwVlvPos: {name a Fan_Coil_Unit: 529 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU288_ChwVlvPos: {name a Fan_Coil_Unit: 288 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU313_ChwVlvPos: {name a Fan_Coil_Unit: 313 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU502_ChwVlvPos: {name a Fan_Coil_Unit: 502 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU471_ChwVlvPos: {name a Fan_Coil_Unit: 471 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU252_ChwVlvPos: {name a Fan_Coil_Unit: 252 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU209_ChwVlvPos: {name a Fan_Coil_Unit: 209 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU202_ChwVlvPos: {name a Fan_Coil_Unit: 202 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU442_ChwVlvPos: {name a Fan_Coil_Unit: 442 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU327_ChwVlvPos: {name a Fan_Coil_Unit: 327 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU312_ChwVlvPos: {name a Fan_Coil_Unit: 312 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU509_ChwVlvPos: {name a Fan_Coil_Unit: 509 a Fan_Coil_Unit}
#    - :BuildingName_01:FC
a Fan_Coil_Unit}
#    - :BuildingName_02:FCU540_ChwVlvPos: {name a Fan_Coil_Unit: 540 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU235_ChwVlvPos: {name a Fan_Coil_Unit: 235 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU428_ChwVlvPos: {name a Fan_Coil_Unit: 428 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU219_ChwVlvPos: {name a Fan_Coil_Unit: 219 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU236_ChwVlvPos: {name a Fan_Coil_Unit: 236 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU210_ChwVlvPos: {name a Fan_Coil_Unit: 210 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU494_ChwVlvPos: {name a Fan_Coil_Unit: 494 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU248_ChwVlvPos: {name a Fan_Coil_Unit: 248 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU516_ChwVlvPos: {name a Fan_Coil_Unit: 516 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU411_ChwVlvPos: {name a Fan_Coil_Unit: 411 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU229_ChwVlvPos: {name a Fan_Coil_Unit: 229 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU407_ChwVlvPos: {name a Fan_Coil_Unit: 407 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU050_ChwVlvPos: {name a Fan_Coil_Unit: 050 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU401_ChwVlvPos: {name a Fan_Coil_Unit: 401 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU319_ChwVlvPos: {name a Fan_Coil_Unit: 319 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU356_ChwVlvPos: {name a Fan_Coil_Unit: 356 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU191_ChwVlvPos: {name a Fan_Coil_Unit: 191 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU391_ChwVlvPos: {name a Fan_Coil_Unit: 391 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU276_ChwVlvPos: {name a Fan_Coil_Unit: 276 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU206_ChwVlvPos: {name a Fan_Coil_Unit: 206 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_ChwVlvPos: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU309_ChwVlvPos: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU365_ChwVlvPos: {name a Fan_Coil_Unit: 365 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU275_ChwVlvPos: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU330_ChwVlvPos: {name a Fan_Coil_Unit: 330 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU444_ChwVlvPos: {name a Fan_Coil_Unit: 444 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU421_ChwVlvPos: {name a Fan_Coil_Unit: 421 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU488_ChwVlvPos: {name a Fan_Coil_Unit: 488 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU446_ChwVlvPos: {name a Fan_Coil_Unit: 446 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU180B_ChwVlvPos: {name a Fan_Coil_Unit: 180 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU467_ChwVlvPos: {name a Fan_Coil_Unit: 467 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_ChwVlvPos: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU283_ChwVlvPos: {name a Fan_Coil_Unit: 283 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU360_ChwVlvPos: {name a Fan_Coil_Unit: 360 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU239_ChwVlvPos: {name a Fan_Coil_Unit: 239 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU263_ChwVlvPos: {name a Fan_Coil_Unit: 263 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU523_ChwVlvPos: {name a Fan_Coil_Unit: 523 a Fan_Coil_Unit}
# Binding for SaTmpEntity with token_classes ['https://brickschema.org/schema/Brick#Air_Handling_Unit', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Entity', 'https://brickschema.org/schema/Brick#Fan_Coil_Unit']
#    - :BuildingName_01:FCU336_OccHtgSptFnl: {name a Fan_Coil_Unit: 336 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU365_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 365 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU180B_UnoccClgSptFnl: {name a Fan_Coil_Unit: 180 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU369_OccClgSptFnl: {name a Fan_Coil_Unit: 369 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU241_EffSysMode: {name a Fan_Coil_Unit: 241 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU392_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 392 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU323_OccHtgSptFnl: {name a Fan_Coil_Unit: 323 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU331_SysMode: {name a Fan_Coil_Unit: 331 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU558_FanMode: {name a Fan_Coil_Unit: 558 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU391_FanMode: {name a Fan_Coil_Unit: 391 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_SysMode: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU319_UnoccClgSptFnl: {name a Fan_Coil_Unit: 319 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU261_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 261 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU416_FanMode: {name a Fan_Coil_Unit: 416 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU452_EffSysMode: {name a Fan_Coil_Unit: 452 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU205_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 205 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU210_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 210 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU352_OccHtgSptFnl: {name a Fan_Coil_Unit: 352 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU307_OccHtgSptFnl: {name a Fan_Coil_Unit: 307 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU277_OccHtgSptFnl: {name a Fan_Coil_Unit: 277 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU289_UnoccClgSptFnl: {name a Fan_Coil_Unit: 289 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU285_OccClgSptFnl: {name a Fan_Coil_Unit: 285 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU282_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 282 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU465_FanMode: {name a Fan_Coil_Unit: 465 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU051_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 051 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU310_UnoccClgSptFnl: {name a Fan_Coil_Unit: 310 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU328_OccClgSptFnl: {name a Fan_Coil_Unit: 328 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU213_UnoccClgSptFnl: {name a Fan_Coil_Unit: 213 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU429_EffSysMode: {name a Fan_Coil_Unit: 429 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU389_FanMode: {name a Fan_Coil_Unit: 389 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU281_EffSysMode: {name a Fan_Coil_Unit: 281 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU283_FanMode: {name a Fan_Coil_Unit: 283 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU491_FanMode: {name a Fan_Coil_Unit: 491 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU224_OccHtgSptFnl: {name a Fan_Coil_Unit: 224 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU306_FanMode: {name a Fan_Coil_Unit: 306 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU559_FanMode: {name a Fan_Coil_Unit: 559 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU241_FanMode: {name a Fan_Coil_Unit: 241 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU443_FanMode: {name a Fan_Coil_Unit: 443 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU491_SysMode: {name a Fan_Coil_Unit: 491 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU211_EffSysMode: {name a Fan_Coil_Unit: 211 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU217_FanMode: {name a Fan_Coil_Unit: 217 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU216_EffSysMode: {name a Fan_Coil_Unit: 216 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU415_FanMode: {name a Fan_Coil_Unit: 415 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU231_OccClgSptFnl: {name a Fan_Coil_Unit: 231 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU489_EffSysMode: {name a Fan_Coil_Unit: 489 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU564_SysMode: {name a Fan_Coil_Unit: 564 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU201_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 201 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU549_EffSysMode: {name a Fan_Coil_Unit: 549 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU281_FanMode: {name a Fan_Coil_Unit: 281 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU329_EffSysMode: {name a Fan_Coil_Unit: 329 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU340_FanMode: {name a Fan_Coil_Unit: 340 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU288_SysMode: {name a Fan_Coil_Unit: 288 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU354_OccClgSptFnl: {name a Fan_Coil_Unit: 354 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU373_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 373 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU349_SysMode: {name a Fan_Coil_Unit: 349 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU359_SysMode: {name a Fan_Coil_Unit: 359 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU392_EffSysMode: {name a Fan_Coil_Unit: 392 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU286_EffSysMode: {name a Fan_Coil_Unit: 286 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU405_SysMode: {name a Fan_Coil_Unit: 405 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU376_FanMode: {name a Fan_Coil_Unit: 376 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU275_SysMode: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU240_OccClgSptFnl: {name a Fan_Coil_Unit: 240 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU310_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 310 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU255_OccClgSptFnl: {name a Fan_Coil_Unit: 255 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU230_EffSysMode: {name a Fan_Coil_Unit: 230 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU252_OccClgSptFnl: {name a Fan_Coil_Unit: 252 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU325_OccClgSptFnl: {name a Fan_Coil_Unit: 325 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU349_FanMode: {name a Fan_Coil_Unit: 349 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU404_SysMode: {name a Fan_Coil_Unit: 404 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU367_FanMode: {name a Fan_Coil_Unit: 367 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU316_EffSysMode: {name a Fan_Coil_Unit: 316 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU313_UnoccClgSptFnl: {name a Fan_Coil_Unit: 313 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU543_SysMode: {name a Fan_Coil_Unit: 543 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU289_FanMode: {name a Fan_Coil_Unit: 289 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU265_OccClgSptFnl: {name a Fan_Coil_Unit: 265 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU305_SysMode: {name a Fan_Coil_Unit: 305 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU473_EffSysMode: {name a Fan_Coil_Unit: 473 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU309_UnoccClgSptFnl: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU505_EffSysMode: {name a Fan_Coil_Unit: 505 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU387_UnoccClgSptFnl: {name a Fan_Coil_Unit: 387 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU538_SysMode: {name a Fan_Coil_Unit: 538 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_EffSysMode: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU458_EffSysMode: {name a Fan_Coil_Unit: 458 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU531_FanMode: {name a Fan_Coil_Unit: 531 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU238_EffSysMode: {name a Fan_Coil_Unit: 238 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU275_OccClgSptFnl: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU359_UnoccClgSptFnl: {name a Fan_Coil_Unit: 359 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU437_SysMode: {name a Fan_Coil_Unit: 437 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU335_UnoccClgSptFnl: {name a Fan_Coil_Unit: 335 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU203_FanMode: {name a Fan_Coil_Unit: 203 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU351_UnoccClgSptFnl: {name a Fan_Coil_Unit: 351 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU344_UnoccClgSptFnl: {name a Fan_Coil_Unit: 344 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU428_EffSysMode: {name a Fan_Coil_Unit: 428 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU238_OccHtgSptFnl: {name a Fan_Coil_Unit: 238 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_OccHtgSptFnl: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU386_FanMode: {name a Fan_Coil_Unit: 386 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU050_SysMode: {name a Fan_Coil_Unit: 050 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU291_EffSysMode: {name a Fan_Coil_Unit: 291 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU349_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 349 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU230_UnoccClgSptFnl: {name a Fan_Coil_Unit: 230 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU337_SysMode: {name a Fan_Coil_Unit: 337 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU241_UnoccClgSptFnl: {name a Fan_Coil_Unit: 241 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU525_SysMode: {name a Fan_Coil_Unit: 525 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU269_FanMode: {name a Fan_Coil_Unit: 269 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU356_OccClgSptFnl: {name a Fan_Coil_Unit: 356 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU419_FanMode: {name a Fan_Coil_Unit: 419 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU503_EffSysMode: {name a Fan_Coil_Unit: 503 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_OccClgSptFnl: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU237_UnoccClgSptFnl: {name a Fan_Coil_Unit: 237 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU355_FanMode: {name a Fan_Coil_Unit: 355 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU367_OccClgSptFnl: {name a Fan_Coil_Unit: 367 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU321_UnoccClgSptFnl: {name a Fan_Coil_Unit: 321 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU337_FanMode: {name a Fan_Coil_Unit: 337 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU311_SysMode: {name a Fan_Coil_Unit: 311 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU352_UnoccClgSptFnl: {name a Fan_Coil_Unit: 352 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU236_FanMode: {name a Fan_Coil_Unit: 236 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU358_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 358 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU254_FanMode: {name a Fan_Coil_Unit: 254 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU323_UnoccClgSptFnl: {name a Fan_Coil_Unit: 323 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU369_EffSysMode: {name a Fan_Coil_Unit: 369 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU375_OccHtgSptFnl: {name a Fan_Coil_Unit: 375 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU456_FanMode: {name a Fan_Coil_Unit: 456 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU479_FanMode: {name a Fan_Coil_Unit: 479 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU367_OccHtgSptFnl: {name a Fan_Coil_Unit: 367 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU412_SysMode: {name a Fan_Coil_Unit: 412 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU313_FanMode: {name a Fan_Coil_Unit: 313 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU364_EffSysMode: {name a Fan_Coil_Unit: 364 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU325_FanMode: {name a Fan_Coil_Unit: 325 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU243_UnoccClgSptFnl: {name a Fan_Coil_Unit: 243 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU286_FanMode: {name a Fan_Coil_Unit: 286 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU303_OccHtgSptFnl: {name a Fan_Coil_Unit: 303 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU371_SysMode: {name a Fan_Coil_Unit: 371 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU459_EffSysMode: {name a Fan_Coil_Unit: 459 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU239_EffSysMode: {name a Fan_Coil_Unit: 239 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU349_OccClgSptFnl: {name a Fan_Coil_Unit: 349 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU563_SysMode: {name a Fan_Coil_Unit: 563 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_EffSysMode: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU211_OccHtgSptFnl: {name a Fan_Coil_Unit: 211 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU224_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 224 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU255_SysMode: {name a Fan_Coil_Unit: 255 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU263_FanMode: {name a Fan_Coil_Unit: 263 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_UnoccClgSptFnl: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU248_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 248 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU201_FanMode: {name a Fan_Coil_Unit: 201 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU339_EffSysMode: {name a Fan_Coil_Unit: 339 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU229_UnoccClgSptFnl: {name a Fan_Coil_Unit: 229 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU180A_SoffitTemp: {name a Fan_Coil_Unit: 180 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU287_SysMode: {name a Fan_Coil_Unit: 287 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU263_SysMode: {name a Fan_Coil_Unit: 263 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU227_OccHtgSptFnl: {name a Fan_Coil_Unit: 227 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU328_FanMode: {name a Fan_Coil_Unit: 328 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU312_OccHtgSptFnl: {name a Fan_Coil_Unit: 312 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU255_OccHtgSptFnl: {name a Fan_Coil_Unit: 255 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU219_UnoccClgSptFnl: {name a Fan_Coil_Unit: 219 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_SysMode: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU301_UnoccClgSptFnl: {name a Fan_Coil_Unit: 301 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU348_SysMode: {name a Fan_Coil_Unit: 348 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU344_SysMode: {name a Fan_Coil_Unit: 344 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU436_SysMode: {name a Fan_Coil_Unit: 436 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU462_FanMode: {name a Fan_Coil_Unit: 462 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU273_OccHtgSptFnl: {name a Fan_Coil_Unit: 273 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU249_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 249 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU303_SysMode: {name a Fan_Coil_Unit: 303 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU343_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 343 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU379_OccClgSptFnl: {name a Fan_Coil_Unit: 379 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU339_OccHtgSptFnl: {name a Fan_Coil_Unit: 339 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU529_EffSysMode: {name a Fan_Coil_Unit: 529 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU286_UnoccClgSptFnl: {name a Fan_Coil_Unit: 286 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU204_SysMode: {name a Fan_Coil_Unit: 204 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU371_OccHtgSptFnl: {name a Fan_Coil_Unit: 371 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU443_EffSysMode: {name a Fan_Coil_Unit: 443 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU309_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU355_EffSysMode: {name a Fan_Coil_Unit: 355 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU362_EffSysMode: {name a Fan_Coil_Unit: 362 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU421_EffSysMode: {name a Fan_Coil_Unit: 421 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU383_OccClgSptFnl: {name a Fan_Coil_Unit: 383 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU382_UnoccClgSptFnl: {name a Fan_Coil_Unit: 382 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU464_FanMode: {name a Fan_Coil_Unit: 464 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU375_SysMode: {name a Fan_Coil_Unit: 375 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU230_OccHtgSptFnl: {name a Fan_Coil_Unit: 230 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU306_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 306 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU407_EffSysMode: {name a Fan_Coil_Unit: 407 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU546_EffSysMode: {name a Fan_Coil_Unit: 546 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU515_SysMode: {name a Fan_Coil_Unit: 515 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU486_EffSysMode: {name a Fan_Coil_Unit: 486 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU360_UnoccClgSptFnl: {name a Fan_Coil_Unit: 360 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU381_SysMode: {name a Fan_Coil_Unit: 381 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU323_EffSysMode: {name a Fan_Coil_Unit: 323 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU377_OccHtgSptFnl: {name a Fan_Coil_Unit: 377 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU255_EffSysMode: {name a Fan_Coil_Unit: 255 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU394_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 394 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU205_FanMode: {name a Fan_Coil_Unit: 205 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU407_FanMode: {name a Fan_Coil_Unit: 407 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU260_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 260 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU363_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 363 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU249_EffSysMode: {name a Fan_Coil_Unit: 249 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU215_OccHtgSptFnl: {name a Fan_Coil_Unit: 215 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU211_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 211 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU428_FanMode: {name a Fan_Coil_Unit: 428 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU329_SysMode: {name a Fan_Coil_Unit: 329 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU251_SysMode: {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU352_FanMode: {name a Fan_Coil_Unit: 352 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU289_OccHtgSptFnl: {name a Fan_Coil_Unit: 289 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU277_SysMode: {name a Fan_Coil_Unit: 277 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU285_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 285 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU201_UnoccClgSptFnl: {name a Fan_Coil_Unit: 201 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU359_OccClgSptFnl: {name a Fan_Coil_Unit: 359 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU438_EffSysMode: {name a Fan_Coil_Unit: 438 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU371_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 371 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU431_FanMode: {name a Fan_Coil_Unit: 431 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU540_SysMode: {name a Fan_Coil_Unit: 540 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU530_EffSysMode: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU423_EffSysMode: {name a Fan_Coil_Unit: 423 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU221_EffSysMode: {name a Fan_Coil_Unit: 221 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU304_SysMode: {name a Fan_Coil_Unit: 304 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU391_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 391 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU542_FanMode: {name a Fan_Coil_Unit: 542 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU552_FanMode: {name a Fan_Coil_Unit: 552 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU317_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 317 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU229_OccHtgSptFnl: {name a Fan_Coil_Unit: 229 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU289_OccClgSptFnl: {name a Fan_Coil_Unit: 289 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU448_FanMode: {name a Fan_Coil_Unit: 448 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU506_FanMode: {name a Fan_Coil_Unit: 506 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU369_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 369 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU419_EffSysMode: {name a Fan_Coil_Unit: 419 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU305_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 305 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU483_SysMode: {name a Fan_Coil_Unit: 483 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU191_EffSysMode: {name a Fan_Coil_Unit: 191 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU539_FanMode: {name a Fan_Coil_Unit: 539 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU213_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 213 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU511_EffSysMode: {name a Fan_Coil_Unit: 511 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU282_UnoccClgSptFnl: {name a Fan_Coil_Unit: 282 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU324_EffSysMode: {name a Fan_Coil_Unit: 324 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU288_FanMode: {name a Fan_Coil_Unit: 288 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU530_SysMode: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU231_FanMode: {name a Fan_Coil_Unit: 231 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU212_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 212 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU305_FanMode: {name a Fan_Coil_Unit: 305 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU507_FanMode: {name a Fan_Coil_Unit: 507 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU264_SysMode: {name a Fan_Coil_Unit: 264 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU377_FanMode: {name a Fan_Coil_Unit: 377 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU383_FanMode: {name a Fan_Coil_Unit: 383 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU348_FanMode: {name a Fan_Coil_Unit: 348 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU521_SysMode: {name a Fan_Coil_Unit: 521 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU358_FanMode: {name a Fan_Coil_Unit: 358 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU449_SysMode: {name a Fan_Coil_Unit: 449 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU315_SysMode: {name a Fan_Coil_Unit: 315 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU507_SysMode: {name a Fan_Coil_Unit: 507 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU517_SysMode: {name a Fan_Coil_Unit: 517 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU259_OccHtgSptFnl: {name a Fan_Coil_Unit: 259 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU048_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 048 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU284_UnoccClgSptFnl: {name a Fan_Coil_Unit: 284 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU254_OccClgSptFnl: {name a Fan_Coil_Unit: 254 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU239_FanMode: {name a Fan_Coil_Unit: 239 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU383_SysMode: {name a Fan_Coil_Unit: 383 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU286_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 286 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU302_OccClgSptFnl: {name a Fan_Coil_Unit: 302 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU337_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 337 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU235_SysMode: {name a Fan_Coil_Unit: 235 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU403_EffSysMode: {name a Fan_Coil_Unit: 403 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU201_EffSysMode: {name a Fan_Coil_Unit: 201 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU191_FanMode: {name a Fan_Coil_Unit: 191 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU336_FanMode: {name a Fan_Coil_Unit: 336 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU377_EffSysMode: {name a Fan_Coil_Unit: 377 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU427_SysMode: {name a Fan_Coil_Unit: 427 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU482_EffSysMode: {name a Fan_Coil_Unit: 482 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU310_SysMode: {name a Fan_Coil_Unit: 310 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU236_UnoccClgSptFnl: {name a Fan_Coil_Unit: 236 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU502_SysMode: {name a Fan_Coil_Unit: 502 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU309_EffSysMode: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU348_OccHtgSptFnl: {name a Fan_Coil_Unit: 348 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU560_SysMode: {name a Fan_Coil_Unit: 560 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU362_SysMode: {name a Fan_Coil_Unit: 362 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU204_OccClgSptFnl: {name a Fan_Coil_Unit: 204 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU225_FanMode: {name a Fan_Coil_Unit: 225 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU341_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 341 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU242_UnoccHtgSptFnl: {name a Fan_Coil_Unit: 242 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU336_SysMode: {name a Fan_Coil_Unit: 336 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU209_OccHtgSptFnl: {name a Fan_Coil_Unit: 209 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU564_EffSysMode: {name a Fan_Coil_Unit: 564 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU304_EffSysMode: {name a Fan_Coil_Unit: 304 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU425_EffSysMode: {name a Fan_Coil_Unit: 425 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU512_FanMode: {name a Fan_Coil_Unit: 512 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU249_OccHtgSptFnl: {name a Fan_Coil_Unit: 249 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU319_SysMode: {name a Fan_Coil_Unit: 319 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU394_OccHtgSptFnl: {name a Fan_Coil_Unit: 394 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU473_SysMode: {name a Fan_Coil_Unit: 473 a Fan_Coil_Unit}
# ...
#    - :BuildingName_01:FCU317_OccCmd: {name a Fan_Coil_Unit: 317 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU438_OccCmd: {name a Fan_Coil_Unit: 438 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU375_OccCmd: {name a Fan_Coil_Unit: 375 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU421_OccCmd: {name a Fan_Coil_Unit: 421 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU231_OccCmd: {name a Fan_Coil_Unit: 231 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU413_OccCmd: {name a Fan_Coil_Unit: 413 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU323_OccCmd: {name a Fan_Coil_Unit: 323 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU429_OccCmd: {name a Fan_Coil_Unit: 429 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU523_OccCmd: {name a Fan_Coil_Unit: 523 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU229_OccCmd: {name a Fan_Coil_Unit: 229 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU415_OccCmd: {name a Fan_Coil_Unit: 415 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU337_OccCmd: {name a Fan_Coil_Unit: 337 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU346_OccCmd: {name a Fan_Coil_Unit: 346 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU391_OccCmd: {name a Fan_Coil_Unit: 391 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU330_OccCmd: {name a Fan_Coil_Unit: 330 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU341_OccCmd: {name a Fan_Coil_Unit: 341 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU461_OccCmd: {name a Fan_Coil_Unit: 461 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU484_OccCmd: {name a Fan_Coil_Unit: 484 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU212_OccCmd: {name a Fan_Coil_Unit: 212 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU541_OccCmd: {name a Fan_Coil_Unit: 541 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU363_OccCmd: {name a Fan_Coil_Unit: 363 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU416_OccCmd: {name a Fan_Coil_Unit: 416 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU392_OccCmd: {name a Fan_Coil_Unit: 392 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU389_OccCmd: {name a Fan_Coil_Unit: 389 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU548_OccCmd: {name a Fan_Coil_Unit: 548 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU377_OccCmd: {name a Fan_Coil_Unit: 377 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU536_OccCmd: {name a Fan_Coil_Unit: 536 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU471_OccCmd: {name a Fan_Coil_Unit: 471 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU563_OccCmd: {name a Fan_Coil_Unit: 563 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU379_OccCmd: {name a Fan_Coil_Unit: 379 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU336_OccCmd: {name a Fan_Coil_Unit: 336 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU462_OccCmd: {name a Fan_Coil_Unit: 462 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU441_OccCmd: {name a Fan_Coil_Unit: 441 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU263_OccCmd: {name a Fan_Coil_Unit: 263 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU404_OccCmd: {name a Fan_Coil_Unit: 404 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU191_OccCmd: {name a Fan_Coil_Unit: 191 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU241_OccCmd: {name a Fan_Coil_Unit: 241 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU285_OccCmd: {name a Fan_Coil_Unit: 285 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU381_OccCmd: {name a Fan_Coil_Unit: 381 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU513_OccCmd: {name a Fan_Coil_Unit: 513 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU554_OccCmd: {name a Fan_Coil_Unit: 554 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU437_OccCmd: {name a Fan_Coil_Unit: 437 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU205_OccCmd: {name a Fan_Coil_Unit: 205 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU201_OccCmd: {name a Fan_Coil_Unit: 201 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU542_OccCmd: {name a Fan_Coil_Unit: 542 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU509_OccCmd: {name a Fan_Coil_Unit: 509 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU277_OccCmd: {name a Fan_Coil_Unit: 277 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU428_OccCmd: {name a Fan_Coil_Unit: 428 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU424_OccCmd: {name a Fan_Coil_Unit: 424 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU394_OccCmd: {name a Fan_Coil_Unit: 394 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU506_OccCmd: {name a Fan_Coil_Unit: 506 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU371_OccCmd: {name a Fan_Coil_Unit: 371 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU292_OccCmd: {name a Fan_Coil_Unit: 292 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU289_OccCmd: {name a Fan_Coil_Unit: 289 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU511_OccCmd: {name a Fan_Coil_Unit: 511 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU309_OccCmd: {name a Fan_Coil_Unit: 309 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU448_OccCmd: {name a Fan_Coil_Unit: 448 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU487_OccCmd: {name a Fan_Coil_Unit: 487 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU288_OccCmd: {name a Fan_Coil_Unit: 288 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU282_OccCmd: {name a Fan_Coil_Unit: 282 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU312_OccCmd: {name a Fan_Coil_Unit: 312 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU352_OccCmd: {name a Fan_Coil_Unit: 352 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU442_OccCmd: {name a Fan_Coil_Unit: 442 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU202_OccCmd: {name a Fan_Coil_Unit: 202 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU390_OccCmd: {name a Fan_Coil_Unit: 390 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU451_OccCmd: {name a Fan_Coil_Unit: 451 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU458_OccCmd: {name a Fan_Coil_Unit: 458 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU419_OccCmd: {name a Fan_Coil_Unit: 419 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU477_OccCmd: {name a Fan_Coil_Unit: 477 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU483_OccCmd: {name a Fan_Coil_Unit: 483 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU401_OccCmd: {name a Fan_Coil_Unit: 401 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU454_OccCmd: {name a Fan_Coil_Unit: 454 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU376_OccCmd: {name a Fan_Coil_Unit: 376 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU209_OccCmd: {name a Fan_Coil_Unit: 209 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU507_OccCmd: {name a Fan_Coil_Unit: 507 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU283_OccCmd: {name a Fan_Coil_Unit: 283 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU382_OccCmd: {name a Fan_Coil_Unit: 382 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU525_OccCmd: {name a Fan_Coil_Unit: 525 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU316_OccCmd: {name a Fan_Coil_Unit: 316 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU494_OccCmd: {name a Fan_Coil_Unit: 494 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU503_OccCmd: {name a Fan_Coil_Unit: 503 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU519_OccCmd: {name a Fan_Coil_Unit: 519 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU469_OccCmd: {name a Fan_Coil_Unit: 469 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU262_OccCmd: {name a Fan_Coil_Unit: 262 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU402_OccCmd: {name a Fan_Coil_Unit: 402 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU342_OccCmd: {name a Fan_Coil_Unit: 342 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU267_OccCmd: {name a Fan_Coil_Unit: 267 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU302_OccCmd: {name a Fan_Coil_Unit: 302 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU476_OccCmd: {name a Fan_Coil_Unit: 476 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU207_OccCmd: {name a Fan_Coil_Unit: 207 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU235_OccCmd: {name a Fan_Coil_Unit: 235 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU286_OccCmd: {name a Fan_Coil_Unit: 286 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU560_OccCmd: {name a Fan_Coil_Unit: 560 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU284_OccCmd: {name a Fan_Coil_Unit: 284 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU230_OccCmd: {name a Fan_Coil_Unit: 230 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU410_OccCmd: {name a Fan_Coil_Unit: 410 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU491_OccCmd: {name a Fan_Coil_Unit: 491 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU340_OccCmd: {name a Fan_Coil_Unit: 340 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU264_OccCmd: {name a Fan_Coil_Unit: 264 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU558_OccCmd: {name a Fan_Coil_Unit: 558 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU403_OccCmd: {name a Fan_Coil_Unit: 403 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU427_OccCmd: {name a Fan_Coil_Unit: 427 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU527_OccCmd: {name a Fan_Coil_Unit: 527 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU329_OccCmd: {name a Fan_Coil_Unit: 329 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU246_OccCmd: {name a Fan_Coil_Unit: 246 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU325_OccCmd: {name a Fan_Coil_Unit: 325 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU463_OccCmd: {name a Fan_Coil_Unit: 463 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU275_OccCmd: {name a Fan_Coil_Unit: 275 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU502_OccCmd: {name a Fan_Coil_Unit: 502 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU228_OccCmd: {name a Fan_Coil_Unit: 228 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU224_OccCmd: {name a Fan_Coil_Unit: 224 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU271_OccCmd: {name a Fan_Coil_Unit: 271 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU338_OccCmd: {name a Fan_Coil_Unit: 338 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU361_OccCmd: {name a Fan_Coil_Unit: 361 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU210_OccCmd: {name a Fan_Coil_Unit: 210 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU219_OccCmd: {name a Fan_Coil_Unit: 219 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU456_OccCmd: {name a Fan_Coil_Unit: 456 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU354_OccCmd: {name a Fan_Coil_Unit: 354 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU358_OccCmd: {name a Fan_Coil_Unit: 358 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU521_OccCmd: {name a Fan_Coil_Unit: 521 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU559_OccCmd: {name a Fan_Coil_Unit: 559 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU387_OccCmd: {name a Fan_Coil_Unit: 387 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU254_OccCmd: {name a Fan_Coil_Unit: 254 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU515_OccCmd: {name a Fan_Coil_Unit: 515 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU505_OccCmd: {name a Fan_Coil_Unit: 505 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU216_OccCmd: {name a Fan_Coil_Unit: 216 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU324_OccCmd: {name a Fan_Coil_Unit: 324 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU479_OccCmd: {name a Fan_Coil_Unit: 479 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU261_OccCmd: {name a Fan_Coil_Unit: 261 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU543_OccCmd: {name a Fan_Coil_Unit: 543 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU510_OccCmd: {name a Fan_Coil_Unit: 510 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU306_OccCmd: {name a Fan_Coil_Unit: 306 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU538_OccCmd: {name a Fan_Coil_Unit: 538 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU551_OccCmd: {name a Fan_Coil_Unit: 551 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU537_OccCmd: {name a Fan_Coil_Unit: 537 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU221_OccCmd: {name a Fan_Coil_Unit: 221 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU439_OccCmd: {name a Fan_Coil_Unit: 439 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU305_OccCmd: {name a Fan_Coil_Unit: 305 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU531_OccCmd: {name a Fan_Coil_Unit: 531 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU552_OccCmd: {name a Fan_Coil_Unit: 552 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU489_OccCmd: {name a Fan_Coil_Unit: 489 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU303_OccCmd: {name a Fan_Coil_Unit: 303 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU248_OccCmd: {name a Fan_Coil_Unit: 248 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU417_OccCmd: {name a Fan_Coil_Unit: 417 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU373_OccCmd: {name a Fan_Coil_Unit: 373 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU310_OccCmd: {name a Fan_Coil_Unit: 310 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU311_OccCmd: {name a Fan_Coil_Unit: 311 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU482_OccCmd: {name a Fan_Coil_Unit: 482 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU243_OccCmd: {name a Fan_Coil_Unit: 243 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU343_OccCmd: {name a Fan_Coil_Unit: 343 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU406_OccCmd: {name a Fan_Coil_Unit: 406 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU385_OccCmd: {name a Fan_Coil_Unit: 385 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU562_OccCmd: {name a Fan_Coil_Unit: 562 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU307_OccCmd: {name a Fan_Coil_Unit: 307 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU388_OccCmd: {name a Fan_Coil_Unit: 388 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU050_OccCmd: {name a Fan_Coil_Unit: 050 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU473_OccCmd: {name a Fan_Coil_Unit: 473 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU203_OccCmd: {name a Fan_Coil_Unit: 203 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU348_OccCmd: {name a Fan_Coil_Unit: 348 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU265_OccCmd: {name a Fan_Coil_Unit: 265 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU412_OccCmd: {name a Fan_Coil_Unit: 412 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU488_OccCmd: {name a Fan_Coil_Unit: 488 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU485_OccCmd: {name a Fan_Coil_Unit: 485 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU279_OccCmd: {name a Fan_Coil_Unit: 279 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU529_OccCmd: {name a Fan_Coil_Unit: 529 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU294_OccCmd: {name a Fan_Coil_Unit: 294 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU501_OccCmd: {name a Fan_Coil_Unit: 501 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU446_OccCmd: {name a Fan_Coil_Unit: 446 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU364_OccCmd: {name a Fan_Coil_Unit: 364 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU411_OccCmd: {name a Fan_Coil_Unit: 411 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU435_OccCmd: {name a Fan_Coil_Unit: 435 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU407_OccCmd: {name a Fan_Coil_Unit: 407 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU281_OccCmd: {name a Fan_Coil_Unit: 281 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU335_OccCmd: {name a Fan_Coil_Unit: 335 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU356_OccCmd: {name a Fan_Coil_Unit: 356 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU517_OccCmd: {name a Fan_Coil_Unit: 517 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU555_OccCmd: {name a Fan_Coil_Unit: 555 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU528_OccCmd: {name a Fan_Coil_Unit: 528 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU351_OccCmd: {name a Fan_Coil_Unit: 351 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU194_OccCmd: {name a Fan_Coil_Unit: 194 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU360_OccCmd: {name a Fan_Coil_Unit: 360 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU227_OccCmd: {name a Fan_Coil_Unit: 227 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU467_OccCmd: {name a Fan_Coil_Unit: 467 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU516_OccCmd: {name a Fan_Coil_Unit: 516 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU512_OccCmd: {name a Fan_Coil_Unit: 512 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU490_OccCmd: {name a Fan_Coil_Unit: 490 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU530_OccCmd: {name a Fan_Coil_Unit: 530 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU444_OccCmd: {name a Fan_Coil_Unit: 444 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU239_OccCmd: {name a Fan_Coil_Unit: 239 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU204_OccCmd: {name a Fan_Coil_Unit: 204 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU443_OccCmd: {name a Fan_Coil_Unit: 443 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU273_OccCmd: {name a Fan_Coil_Unit: 273 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU217_OccCmd: {name a Fan_Coil_Unit: 217 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU464_OccCmd: {name a Fan_Coil_Unit: 464 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU386_OccCmd: {name a Fan_Coil_Unit: 386 a Fan_Coil_Unit}
#    - :BuildingName_02:FCU486_OccCmd: {name a Fan_Coil_Unit: 486 a Fan_Coil_Unit}
#    - :BuildingName_01:FCU269_OccCmd: {name a Fan_Coil_Unit: 269 a Fan_Coil_Unit}

# %%
# group the bindings by template, then by the value of the name. 
bindings_by_name_by_template_name = {}
for template_name, bindings_list in bindings_by_template_name.items():
    bindings_by_name = defaultdict(list)
    
    for bindings in bindings_list:
        name = next((
            token.identifier 
            for param, token in bindings.bindings.items()
            if param.name == "name"
        ), None)
        
        bindings_by_name[name].append(bindings)

    bindings_by_name_by_template_name[template_name] = bindings_by_name

for template_name, bindings_by_name in bindings_by_name_by_template_name.items():
    for name, bindings in bindings_by_name.items():
        print(f"{len(bindings)} bindings for {template_name} where name is {name}")
# Out:
# 18 bindings for SaTmpEntity where name is 503
# 21 bindings for SaTmpEntity where name is 362
# 21 bindings for SaTmpEntity where name is 343
# 20 bindings for SaTmpEntity where name is 301
# 18 bindings for SaTmpEntity where name is 448
# 18 bindings for SaTmpEntity where name is 530
# 18 bindings for SaTmpEntity where name is 529
# 22 bindings for SaTmpEntity where name is 288
# 21 bindings for SaTmpEntity where name is 313
# 18 bindings for SaTmpEntity where name is 502
# 18 bindings for SaTmpEntity where name is 471
# 19 bindings for SaTmpEntity where name is 252
# 22 bindings for SaTmpEntity where name is 209
# 22 bindings for SaTmpEntity where name is 202
# 18 bindings for SaTmpEntity where name is 442
# 21 bindings for SaTmpEntity where name is 327
# 21 bindings for SaTmpEntity where name is 312
# 18 bindings for SaTmpEntity where name is 509
# 22 bindings for SaTmpEntity where name is 213
# 22 bindings for SaTmpEntity where name is 281
# 18 bindings for SaTmpEntity where name is 429
# 19 bindings for SaTmpEntity where name is 317
# 22 bindings for SaTmpEntity where name is 251
# 18 bindings for SaTmpEntity where name is 513
# 22 bindings for SaTmpEntity where name is 215
# 18 bindings for SaTmpEntity where name is 403
# 21 bindings for SaTmpEntity where name is 354
# 21 bindings for SaTmpEntity where name is 340
# 21 bindings for SaTmpEntity where name is 361
# 18 bindings for SaTmpEntity where name is 538
# 21 bindings for SaTmpEntity where name is 316
# 18 bindings for SaTmpEntity where name is 482
# 18 bindings for SaTmpEntity where name is 489
# 22 bindings for SaTmpEntity where name is 238
# 22 bindings for SaTmpEntity where name is 277
# 22 bindings for SaTmpEntity where name is 285
# 21 bindings for SaTmpEntity where name is 346
# 20 bindings for SaTmpEntity where name is 304
# 21 bindings for SaTmpEntity where name is 376
# 18 bindings for SaTmpEntity where name is 558
# 21 bindings for SaTmpEntity where name is 315
# 18 bindings for SaTmpEntity where name is 541
# 18 bindings for SaTmpEntity where name is 469
# 22 bindings for SaTmpEntity where name is 279
# 21 bindings for SaTmpEntity where name is 364
# 18 bindings for SaTmpEntity where name is 537
# 22 bindings for SaTmpEntity where name is 228
# 18 bindings for SaTmpEntity where name is 531
# 22 bindings for SaTmpEntity where name is 290
# 18 bindings for SaTmpEntity where name is 223
# 21 bindings for SaTmpEntity where name is 388
# 22 bindings for SaTmpEntity where name is 269
# 18 bindings for SaTmpEntity where name is 501
# 21 bindings for SaTmpEntity where name is 385
# 22 bindings for SaTmpEntity where name is 264
# 18 bindings for SaTmpEntity where name is 483
# 22 bindings for SaTmpEntity where name is 287
# 18 bindings for SaTmpEntity where name is 441
# 18 bindings for SaTmpEntity where name is 458
# 17 bindings for SaTmpEntity where name is 564
# 21 bindings for SaTmpEntity where name is 383
# 19 bindings for SaTmpEntity where name is 324
# 22 bindings for SaTmpEntity where name is 262
# 18 bindings for SaTmpEntity where name is 521
# 22 bindings for SaTmpEntity where name is 212
# 18 bindings for SaTmpEntity where name is 409
# 21 bindings for SaTmpEntity where name is 359
# 18 bindings for SaTmpEntity where name is 506
# 19 bindings for SaTmpEntity where name is 352
# 21 bindings for SaTmpEntity where name is 328
# 18 bindings for SaTmpEntity where name is 416
# 21 bindings for SaTmpEntity where name is 325
# 21 bindings for SaTmpEntity where name is 351
# 21 bindings for SaTmpEntity where name is 377
# 21 bindings for SaTmpEntity where name is 306
# 21 bindings for SaTmpEntity where name is 329
# 17 bindings for SaTmpEntity where name is 256
# 21 bindings for SaTmpEntity where name is 331
# 22 bindings for SaTmpEntity where name is 230
# 22 bindings for SaTmpEntity where name is 205
# 22 bindings for SaTmpEntity where name is 211
# 18 bindings for SaTmpEntity where name is 555
# 22 bindings for SaTmpEntity where name is 203
# 15 bindings for SaTmpEntity where name is 524
# 22 bindings for SaTmpEntity where name is 255
# 20 bindings for SaTmpEntity where name is 363
# 22 bindings for SaTmpEntity where name is 282
# 22 bindings for SaTmpEntity where name is 204
# 21 bindings for SaTmpEntity where name is 342
# 22 bindings for SaTmpEntity where name is 254
# 20 bindings for SaTmpEntity where name is 303
# 18 bindings for SaTmpEntity where name is 460
# 18 bindings for SaTmpEntity where name is 479
# 18 bindings for SaTmpEntity where name is 551
# 22 bindings for SaTmpEntity where name is 227
# 13 bindings for SaTmpEntity where name is 556
# 18 bindings for SaTmpEntity where name is 542
# 18 bindings for SaTmpEntity where name is 404
# 18 bindings for SaTmpEntity where name is 425
# 18 bindings for SaTmpEntity where name is 549
# 18 bindings for SaTmpEntity where name is 437
# 21 bindings for SaTmpEntity where name is 387
# 18 bindings for SaTmpEntity where name is 462
# 36 bindings for SaTmpEntity where name is 180
# 21 bindings for SaTmpEntity where name is 386
# 18 bindings for SaTmpEntity where name is 543
# 21 bindings for SaTmpEntity where name is 194
# 22 bindings for SaTmpEntity where name is 244
# 19 bindings for SaTmpEntity where name is 216
# 18 bindings for SaTmpEntity where name is 528
# 18 bindings for SaTmpEntity where name is 548
# 21 bindings for SaTmpEntity where name is 311
# 18 bindings for SaTmpEntity where name is 465
# 21 bindings for SaTmpEntity where name is 394
# 22 bindings for SaTmpEntity where name is 221
# 19 bindings for SaTmpEntity where name is 224
# 18 bindings for SaTmpEntity where name is 464
# 17 bindings for SaTmpEntity where name is 258
# 18 bindings for SaTmpEntity where name is 511
# 17 bindings for SaTmpEntity where name is 260
# 15 bindings for SaTmpEntity where name is 048
# 22 bindings for SaTmpEntity where name is 246
# 14 bindings for SaTmpEntity where name is 051
# 18 bindings for SaTmpEntity where name is 554
# 21 bindings for SaTmpEntity where name is 344
# 18 bindings for SaTmpEntity where name is 438
# 18 bindings for SaTmpEntity where name is 504
# 21 bindings for SaTmpEntity where name is 349
# 22 bindings for SaTmpEntity where name is 289
# 18 bindings for SaTmpEntity where name is 507
# 21 bindings for SaTmpEntity where name is 305
# 22 bindings for SaTmpEntity where name is 265
# 18 bindings for SaTmpEntity where name is 487
# 22 bindings for SaTmpEntity where name is 231
# 18 bindings for SaTmpEntity where name is 525
# 15 bindings for SaTmpEntity where name is 552
# 18 bindings for SaTmpEntity where name is 491
# 18 bindings for SaTmpEntity where name is 560
# 18 bindings for SaTmpEntity where name is 431
# 18 bindings for SaTmpEntity where name is 463
# 18 bindings for SaTmpEntity where name is 405
# 18 bindings for SaTmpEntity where name is 413
# 21 bindings for SaTmpEntity where name is 389
# 21 bindings for SaTmpEntity where name is 367
# 18 bindings for SaTmpEntity where name is 517
# 18 bindings for SaTmpEntity where name is 536
# 18 bindings for SaTmpEntity where name is 476
# 22 bindings for SaTmpEntity where name is 217
# 22 bindings for SaTmpEntity where name is 291
# 18 bindings for SaTmpEntity where name is 427
# 22 bindings for SaTmpEntity where name is 267
# 21 bindings for SaTmpEntity where name is 392
# 18 bindings for SaTmpEntity where name is 419
# 18 bindings for SaTmpEntity where name is 477
# 22 bindings for SaTmpEntity where name is 207
# 18 bindings for SaTmpEntity where name is 436
# 21 bindings for SaTmpEntity where name is 390
# 21 bindings for SaTmpEntity where name is 310
# 18 bindings for SaTmpEntity where name is 505
# 18 bindings for SaTmpEntity where name is 449
# 15 bindings for SaTmpEntity where name is 424
# 18 bindings for SaTmpEntity where name is 440
# 18 bindings for SaTmpEntity where name is 527
# 9 bindings for SaTmpEntity where name is 475
# 18 bindings for SaTmpEntity where name is 490
# 18 bindings for SaTmpEntity where name is 544
# 18 bindings for SaTmpEntity where name is 451
# 18 bindings for SaTmpEntity where name is 410
# 21 bindings for SaTmpEntity where name is 337
# 21 bindings for SaTmpEntity where name is 335
# 21 bindings for SaTmpEntity where name is 358
# 21 bindings for SaTmpEntity where name is 321
# 21 bindings for SaTmpEntity where name is 323
# 20 bindings for SaTmpEntity where name is 302
# 18 bindings for SaTmpEntity where name is 484
# 18 bindings for SaTmpEntity where name is 417
# 13 bindings for SaTmpEntity where name is 481
# 15 bindings for SaTmpEntity where name is 452
# 18 bindings for SaTmpEntity where name is 486
# 21 bindings for SaTmpEntity where name is 348
# 21 bindings for SaTmpEntity where name is 339
# 22 bindings for SaTmpEntity where name is 225
# 18 bindings for SaTmpEntity where name is 406
# 21 bindings for SaTmpEntity where name is 273
# 18 bindings for SaTmpEntity where name is 456
# 22 bindings for SaTmpEntity where name is 261
# 18 bindings for SaTmpEntity where name is 435
# 21 bindings for SaTmpEntity where name is 336
# 21 bindings for SaTmpEntity where name is 379
# 13 bindings for SaTmpEntity where name is 455
# 22 bindings for SaTmpEntity where name is 201
# 22 bindings for SaTmpEntity where name is 243
# 19 bindings for SaTmpEntity where name is 375
# 22 bindings for SaTmpEntity where name is 271
# 18 bindings for SaTmpEntity where name is 454
# 18 bindings for SaTmpEntity where name is 461
# 18 bindings for SaTmpEntity where name is 459
# 21 bindings for SaTmpEntity where name is 382
# 18 bindings for SaTmpEntity where name is 402
# 18 bindings for SaTmpEntity where name is 439
# 18 bindings for SaTmpEntity where name is 415
# 21 bindings for SaTmpEntity where name is 338
# 22 bindings for SaTmpEntity where name is 240
# 18 bindings for SaTmpEntity where name is 430
# 17 bindings for SaTmpEntity where name is 259
# 21 bindings for SaTmpEntity where name is 371
# 22 bindings for SaTmpEntity where name is 284
# 21 bindings for SaTmpEntity where name is 355
# 18 bindings for SaTmpEntity where name is 535
# 18 bindings for SaTmpEntity where name is 563
# 13 bindings for SaTmpEntity where name is 492
# 18 bindings for SaTmpEntity where name is 443
# 21 bindings for SaTmpEntity where name is 307
# 22 bindings for SaTmpEntity where name is 241
# 21 bindings for SaTmpEntity where name is 369
# 18 bindings for SaTmpEntity where name is 559
# 18 bindings for SaTmpEntity where name is 561
# 18 bindings for SaTmpEntity where name is 510
# 18 bindings for SaTmpEntity where name is 546
# 18 bindings for SaTmpEntity where name is 515
# 18 bindings for SaTmpEntity where name is 562
# 18 bindings for SaTmpEntity where name is 485
# 22 bindings for SaTmpEntity where name is 249
# 21 bindings for SaTmpEntity where name is 384
# 18 bindings for SaTmpEntity where name is 519
# 18 bindings for SaTmpEntity where name is 512
# 22 bindings for SaTmpEntity where name is 286
# 18 bindings for SaTmpEntity where name is 423
# 21 bindings for SaTmpEntity where name is 381
# 18 bindings for SaTmpEntity where name is 412
# 22 bindings for SaTmpEntity where name is 237
# 21 bindings for SaTmpEntity where name is 341
# 18 bindings for SaTmpEntity where name is 539
# 18 bindings for SaTmpEntity where name is 473
# 22 bindings for SaTmpEntity where name is 294
# 21 bindings for SaTmpEntity where name is 373
# 18 bindings for SaTmpEntity where name is 540
# 22 bindings for SaTmpEntity where name is 235
# 18 bindings for SaTmpEntity where name is 428
# 22 bindings for SaTmpEntity where name is 219
# 22 bindings for SaTmpEntity where name is 236
# 22 bindings for SaTmpEntity where name is 210
# 18 bindings for SaTmpEntity where name is 494
# 22 bindings for SaTmpEntity where name is 248
# 18 bindings for SaTmpEntity where name is 516
# 18 bindings for SaTmpEntity where name is 411
# 22 bindings for SaTmpEntity where name is 229
# 18 bindings for SaTmpEntity where name is 407
# 17 bindings for SaTmpEntity where name is 050
# 18 bindings for SaTmpEntity where name is 401
# 21 bindings for SaTmpEntity where name is 319
# 21 bindings for SaTmpEntity where name is 356
# 23 bindings for SaTmpEntity where name is 191
# 21 bindings for SaTmpEntity where name is 391
# 21 bindings for SaTmpEntity where name is 276
# 22 bindings for SaTmpEntity where name is 206
# 22 bindings for SaTmpEntity where name is 292
# 20 bindings for SaTmpEntity where name is 309
# 16 bindings for SaTmpEntity where name is 365
# 19 bindings for SaTmpEntity where name is 275
# 21 bindings for SaTmpEntity where name is 330
# 18 bindings for SaTmpEntity where name is 444
# 18 bindings for SaTmpEntity where name is 421
# 18 bindings for SaTmpEntity where name is 488
# 18 bindings for SaTmpEntity where name is 446
# 18 bindings for SaTmpEntity where name is 467
# 22 bindings for SaTmpEntity where name is 242
# 22 bindings for SaTmpEntity where name is 283
# 21 bindings for SaTmpEntity where name is 360
# 22 bindings for SaTmpEntity where name is 239
# 22 bindings for SaTmpEntity where name is 263
# 18 bindings for SaTmpEntity where name is 523

# %%
# example: labels with best bindings on SaTmpEntity where name is "201"
for bindings in bindings_by_name_by_template_name["SaTmpEntity"]["251"]:
    print(bindings.bindings)
# Out:
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {sat a Supply_Air_Temperature_Sensor: :BuildingName_01:FCU251_UI22_SaTmp a Supply_Air_Temperature_Sensor, name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
# {name a Fan_Coil_Unit: 251 a Fan_Coil_Unit}
