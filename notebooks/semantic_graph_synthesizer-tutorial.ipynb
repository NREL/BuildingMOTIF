# %%
from pathlib import Path
import json
import os

from rdflib import URIRef, Namespace

from buildingmotif import BuildingMOTIF
from buildingmotif.dataclasses import Library, Template
from buildingmotif.semantic_graph_synthesizer.bindings_utils import unify_bindings, evaluate_bindings
from buildingmotif.semantic_graph_synthesizer.classes import TokenizedLabel
from buildingmotif.semantic_graph_synthesizer.semantic_graph_synthesizer import SemanticGraphSynthesizer
from buildingmotif.semantic_graph_synthesizer.bipartite_token_mapper import BipartiteTokenMapper

import logging
logger = logging.getLogger()
logger.setLevel(logging.ERROR)

BLDG = Namespace("urn:building/")
PROJECT_DIR = Path(os.getcwd()).resolve().parent
bm = BuildingMOTIF("sqlite://")

# %%
# These are our Templates
Library.load(ontology_graph="https://github.com/BrickSchema/Brick/releases/download/nightly/Brick.ttl")
equiment_templates = Library.load(directory=str(PROJECT_DIR / "gabes_points" / "equiment_templates"))
templates = equiment_templates.get_templates()

for template in templates:
    template.inline_dependencies()
    print(f"{template.name} =======================")
    print(template.body.serialize(format="ttl"))
    print()
# Out:
# 2023-10-09 12:46:53,734 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6922
# 2023-10-09 12:46:53,736 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6924
# 2023-10-09 12:46:53,737 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6926
# 2023-10-09 12:46:53,737 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6928
# 2023-10-09 12:46:53,738 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6930
# 2023-10-09 12:46:53,739 | root |  WARNING: Warning: could not find dependee http://data.ashrae.org/bacnet/2020#BACnetDevice
# 2023-10-09 12:46:53,740 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6972
# 2023-10-09 12:46:53,741 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6974
# 2023-10-09 12:46:53,741 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6976
# 2023-10-09 12:46:53,742 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6978
# 2023-10-09 12:46:53,742 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b6980
# 2023-10-09 12:46:53,743 | root |  WARNING: Warning: could not find dependee https://brickschema.org/schema/Brick/ref#ifcProject
# 2023-10-09 12:46:53,744 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7045
# 2023-10-09 12:46:53,746 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7047
# 2023-10-09 12:46:53,746 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7049
# 2023-10-09 12:46:53,747 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7051
# 2023-10-09 12:46:53,748 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7053
# 2023-10-09 12:46:53,748 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7011
# 2023-10-09 12:46:53,749 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7013
# 2023-10-09 12:46:53,750 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7015
# 2023-10-09 12:46:53,750 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7017
# 2023-10-09 12:46:53,751 | root |  WARNING: Warning: could not find dependee n4344d56466c2426fbb28184a3917d0f4b7019
# SaTmpEntity =======================
# @prefix ns1: <https://brickschema.org/schema/Brick#> .
#
# <urn:___param___#name> a ns1:Fan_Coil_Unit ;
#     ns1:hasPoint <urn:___param___#sat> .
#
# <urn:___param___#sat> a ns1:Supply_Air_Temperature_Sensor .
#
#
#
# fcu =======================
# @prefix ns1: <https://brickschema.org/schema/Brick#> .
#
# <urn:___param___#name> a ns1:Fan_Coil_Unit ;
#     ns1:feeds <urn:___param___#zone> ;
#     ns1:hasPart <urn:___param___#chw_coil>,
#         <urn:___param___#hw_coil> ;
#     ns1:hasPoint <urn:___param___#occ_clg_sp>,
#         <urn:___param___#occ_cmd>,
#         <urn:___param___#occ_htg_sp>,
#         <urn:___param___#occ_status>,
#         <urn:___param___#supply_temp>,
#         <urn:___param___#unocc_clg_sp>,
#         <urn:___param___#unocc_htg_sp> .
#
# <urn:___param___#zone> a ns1:HVAC_Zone ;
#     ns1:hasPart <urn:___param___#room> .
#
#
#
# room =======================
# @prefix ns1: <https://brickschema.org/schema/Brick#> .
#
# <urn:___param___#name> a ns1:Space ;
#     ns1:hasPoint <urn:___param___#relative_humidity>,
#         <urn:___param___#temp> .
#
#
#
# heating_coil =======================
# @prefix ns1: <https://brickschema.org/schema/Brick#> .
#
# <urn:___param___#name> a ns1:Heating_Coil ;
#     ns1:hasPart <urn:___param___#hw_vlv> .
#
# <urn:___param___#hw_vlv> ns1:hasPoint <urn:___param___#position> .
#
#
#
# cooling_coil =======================
# @prefix ns1: <https://brickschema.org/schema/Brick#> .
#
# <urn:___param___#name> a ns1:Cooling_Coil ;
#     ns1:hasPart <urn:___param___#chw_vlv> .
#
# <urn:___param___#chw_vlv> ns1:hasPoint <urn:___param___#position> .

# %%
# These are our points - there's alot
with open(PROJECT_DIR / "gabes_points" / "tokens.json") as f:
    labels_and_tokens = json.load(f)
    labels = [TokenizedLabel.from_dict(x) for x in labels_and_tokens]

len(labels)
# Out:
# 5319

# %%
# This is what a point looks like
label = labels[0]

label
# Out:
# :BuildingName_02:FCU503_ChwVlvPos:
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)

# %%
# We are going to use this to get bindings. 
sgs = SemanticGraphSynthesizer()

# %%
# here's how to get one labels bindings
bindings = sgs.find_bindings_for_label(templates, labels[0])

print(bindings.template.name)
print(bindings.bindings)
print(bindings.cost)
# Out:
# fcu
# {'name': 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit), 'chw_coil-chw_vlv': :BuildingName_02:FCU503_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)}
# Cost(edge_cost=0.0, params_dropped=16, tokens_dropped=2)

# %%
# we can group labels into labelsets to greatly reduce the ammount of work doing this in bulk takes. 
labelsets = sgs._group_labels_by_tokens(labels)

labelsets[0]
# Out:
# LabelSet(token_classes=[rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Handling_Unit'), rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Valve'), rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entity'), rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Coil_Unit')], labels=[:BuildingName_02:FCU503_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU503_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU362_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU362_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 362 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU343_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU343_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 343 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU301_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU301_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 301 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU448_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU448_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 448 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU530_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU530_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU529_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU529_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 529 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU288_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU288_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 288 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU313_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU313_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 313 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU502_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU502_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 502 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU471_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU471_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 471 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU252_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU252_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 252 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU209_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU209_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 209 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU202_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU202_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 202 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU442_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU442_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 442 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU327_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU327_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 327 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU312_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU312_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 312 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU509_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU509_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 509 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU213_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU213_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 213 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU281_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU281_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 281 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU429_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU429_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 429 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU317_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU317_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 317 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU251_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU251_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 251 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU513_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU513_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 513 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU215_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU215_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 215 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU403_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU403_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 403 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU354_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU354_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 354 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU340_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU340_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 340 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU361_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU361_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 361 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU538_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU538_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 538 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU316_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU316_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 316 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU482_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU482_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 482 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU489_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU489_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 489 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU238_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU238_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 238 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU277_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU277_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 277 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU285_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU285_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 285 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU346_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU346_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 346 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU304_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU304_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 304 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU376_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU376_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 376 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU558_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU558_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 558 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU315_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU315_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 315 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU541_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU541_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 541 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU469_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU469_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 469 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU279_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU279_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 279 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU364_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU364_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 364 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU537_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU537_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 537 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU228_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU228_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 228 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU531_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU531_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 531 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU290_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU290_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 290 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU223_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU223_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 223 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU388_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU388_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 388 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU269_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU269_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 269 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU501_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU501_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 501 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU385_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU385_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 385 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU264_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU264_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 264 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU483_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU483_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 483 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU287_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU287_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 287 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU441_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU441_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 441 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU458_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU458_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 458 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU564_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU564_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 564 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU383_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU383_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 383 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU324_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU324_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 324 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU262_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU262_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 262 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU521_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU521_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 521 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU212_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU212_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 212 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU409_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU409_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 409 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU359_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU359_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 359 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU506_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU506_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 506 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU352_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU352_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 352 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU328_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU328_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 328 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU416_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU416_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 416 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU325_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU325_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 325 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU351_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU351_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 351 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU377_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU377_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 377 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU306_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU306_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 306 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU329_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU329_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 329 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU256_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU256_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 256 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU331_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU331_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 331 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU230_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU230_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 230 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU205_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU205_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 205 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU211_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU211_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 211 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU555_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU555_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 555 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU203_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU203_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 203 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU524_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU524_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 524 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU255_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU255_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 255 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU363_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU363_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 363 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU282_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU282_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 282 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU204_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU204_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 204 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU342_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU342_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 342 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU254_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU254_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 254 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU303_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU303_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 303 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU460_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU460_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 460 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU479_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU479_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 479 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU551_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU551_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 551 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU227_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU227_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 227 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU556_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU556_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 556 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU542_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU542_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 542 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU404_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU404_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 404 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU425_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU425_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 425 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU549_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU549_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 549 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU437_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU437_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 437 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU387_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU387_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 387 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU462_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU462_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 462 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU180A_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU180A_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 180 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU386_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU386_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 386 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU543_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU543_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 543 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU194_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU194_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 194 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU244_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU244_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 244 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU216_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU216_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 216 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU528_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU528_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 528 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU548_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU548_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 548 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU311_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU311_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 311 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU465_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU465_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 465 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU394_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU394_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 394 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU221_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU221_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 221 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU224_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU224_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 224 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU464_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU464_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 464 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU258_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU258_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 258 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU511_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU511_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 511 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU260_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU260_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 260 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU048_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU048_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 048 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU246_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU246_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 246 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU051_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU051_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 051 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU554_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU554_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 554 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU344_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU344_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 344 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU438_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU438_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 438 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU504_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU504_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 504 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU349_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU349_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 349 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU289_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU289_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 289 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU507_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU507_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 507 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU305_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU305_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 305 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU265_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU265_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 265 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU487_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU487_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 487 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU231_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU231_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 231 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU525_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU525_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 525 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU552_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU552_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 552 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU491_ChwVlvPos:
# ...
#     - :BuildingName_02:FCU423_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 423 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU381_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU381_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 381 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU412_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU412_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 412 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU237_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU237_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 237 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU341_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU341_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 341 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU539_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU539_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 539 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU473_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU473_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 473 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU294_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU294_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 294 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU373_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU373_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 373 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU540_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU540_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 540 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU235_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU235_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 235 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU428_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU428_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 428 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU219_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU219_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 219 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU236_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU236_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 236 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU210_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU210_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 210 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU494_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU494_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 494 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU248_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU248_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 248 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU516_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU516_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 516 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU411_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU411_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 411 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU229_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU229_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 229 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU407_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU407_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 407 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU050_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU050_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 050 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU401_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU401_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 401 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU319_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU319_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 319 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU356_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU356_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 356 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU191_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU191_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 191 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU391_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU391_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 391 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU276_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU276_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 276 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU206_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU206_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 206 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU292_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU292_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 292 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU309_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU309_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 309 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU365_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU365_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 365 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU275_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU275_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 275 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU330_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU330_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 330 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU444_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU444_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 444 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU421_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU421_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 421 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU488_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU488_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 488 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU446_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU446_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 446 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU180B_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU180B_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 180 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU467_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU467_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 467 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU242_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU242_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 242 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU283_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU283_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 283 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU360_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU360_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 360 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU239_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU239_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 239 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_01:FCU263_ChwVlvPos:
#     - 01 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_01:FCU263_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 263 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU523_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU523_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 523 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# ])

# %%
# See? only 13 labelsets total
len(labelsets)
# Out:
# 13

# %%
# find_bindings_for_labels is like find_bindings_for_label, but bulk. It uses labelsets to go fast. 
bindings_list = sgs.find_bindings_for_labels(templates, labels)

len(bindings_list)
# Out:
# 5319

# %%
# we can build out more meaningful bindings by unifying the ones on the same template with the same name
unified_bindings_list = unify_bindings(bindings_list)

unified_bindings_list[0]
# Out:
# UnifiedBindings(labels=[:BuildingName_02:FCU503_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU503_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU503_EffOcc:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_EffOcc (type https://brickschema.org/schema/Brick#Occupancy_Status)
# , :BuildingName_02:FCU503_UnoccHtgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_UnoccHtgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint)
# , :BuildingName_02:FCU503_OccClgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_OccClgSpt (type https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint)
# , :BuildingName_02:FCU503_RoomTmp:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU503_RoomTmp (type https://brickschema.org/schema/Brick#Air_Temperature_Sensor)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU503_HwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_HwVlvPos (type https://brickschema.org/schema/Brick#Hot_Water_Valve)
# , :BuildingName_02:FCU503_OccHtgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_OccHtgSpt (type https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint)
# , :BuildingName_02:FCU503_UnoccClgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_UnoccClgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint)
# , :BuildingName_02:FCU503_OccCmd:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU503_OccCmd (type https://brickschema.org/schema/Brick#Occupancy_Command)
# ], template=Template(_id=-1, _name='fcu', body=<Graph identifier=N4339bc6041464185861cd5c5e72fc459 (<class 'rdflib.graph.Graph'>)>, optional_args=['occ_cmd', 'unocc_clg_sp', 'unocc_htg_sp', 'occ_status', 'occ_htg_sp', 'occ_clg_sp'], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x1102b1fd0>), bindings={'name': 503 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit), 'chw_coil-chw_vlv': :BuildingName_02:FCU503_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve), 'occ_status': :BuildingName_02:FCU503_EffOcc (type https://brickschema.org/schema/Brick#Occupancy_Status), 'unocc_htg_sp': :BuildingName_02:FCU503_UnoccHtgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint), 'occ_clg_sp': :BuildingName_02:FCU503_OccClgSpt (type https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint), 'room-temp': :BuildingName_02:FCU503_RoomTmp (type https://brickschema.org/schema/Brick#Air_Temperature_Sensor), 'hw_coil-hw_vlv': :BuildingName_02:FCU503_HwVlvPos (type https://brickschema.org/schema/Brick#Hot_Water_Valve), 'occ_htg_sp': :BuildingName_02:FCU503_OccHtgSpt (type https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint), 'unocc_clg_sp': :BuildingName_02:FCU503_UnoccClgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint), 'occ_cmd': :BuildingName_02:FCU503_OccCmd (type https://brickschema.org/schema/Brick#Occupancy_Command)}, cost=Cost(edge_cost=0.0, params_dropped=16, tokens_dropped=2))

# %%
# much fewer but more exciting!
len(unified_bindings_list)
# Out:
# 544

# %%
# See? Very cool.
unified_bindings = unified_bindings_list[5]

unified_bindings
# Out:
# UnifiedBindings(labels=[:BuildingName_02:FCU530_ChwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU530_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU530_EffOcc:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_EffOcc (type https://brickschema.org/schema/Brick#Occupancy_Status)
# , :BuildingName_02:FCU530_UnoccHtgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_UnoccHtgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint)
# , :BuildingName_02:FCU530_OccClgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_OccClgSpt (type https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint)
# , :BuildingName_02:FCU530_RoomTmp:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - :BuildingName_02:FCU530_RoomTmp (type https://brickschema.org/schema/Brick#Air_Temperature_Sensor)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
# , :BuildingName_02:FCU530_HwVlvPos:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_HwVlvPos (type https://brickschema.org/schema/Brick#Hot_Water_Valve)
# , :BuildingName_02:FCU530_OccHtgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_OccHtgSpt (type https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint)
# , :BuildingName_02:FCU530_UnoccClgSpt:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_UnoccClgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint)
# , :BuildingName_02:FCU530_OccCmd:
#     - 02 (type https://brickschema.org/schema/Brick#Air_Handling_Unit)
#     - BuildingName (type https://brickschema.org/schema/Brick#Entity)
#     - 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit)
#     - :BuildingName_02:FCU530_OccCmd (type https://brickschema.org/schema/Brick#Occupancy_Command)
# ], template=Template(_id=-1, _name='fcu', body=<Graph identifier=N4339bc6041464185861cd5c5e72fc459 (<class 'rdflib.graph.Graph'>)>, optional_args=['occ_cmd', 'unocc_clg_sp', 'unocc_htg_sp', 'occ_status', 'occ_htg_sp', 'occ_clg_sp'], _bm=<buildingmotif.building_motif.building_motif.BuildingMOTIF object at 0x1102b1fd0>), bindings={'name': 530 (type https://brickschema.org/schema/Brick#Fan_Coil_Unit), 'chw_coil-chw_vlv': :BuildingName_02:FCU530_ChwVlvPos (type https://brickschema.org/schema/Brick#Chilled_Water_Valve), 'occ_status': :BuildingName_02:FCU530_EffOcc (type https://brickschema.org/schema/Brick#Occupancy_Status), 'unocc_htg_sp': :BuildingName_02:FCU530_UnoccHtgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint), 'occ_clg_sp': :BuildingName_02:FCU530_OccClgSpt (type https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint), 'room-temp': :BuildingName_02:FCU530_RoomTmp (type https://brickschema.org/schema/Brick#Air_Temperature_Sensor), 'hw_coil-hw_vlv': :BuildingName_02:FCU530_HwVlvPos (type https://brickschema.org/schema/Brick#Hot_Water_Valve), 'occ_htg_sp': :BuildingName_02:FCU530_OccHtgSpt (type https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint), 'unocc_clg_sp': :BuildingName_02:FCU530_UnoccClgSpt (type https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint), 'occ_cmd': :BuildingName_02:FCU530_OccCmd (type https://brickschema.org/schema/Brick#Occupancy_Command)}, cost=Cost(edge_cost=0.0, params_dropped=16, tokens_dropped=2))

# %%
# each unified binding can be evaluated into a graph. 
model = evaluate_bindings(unified_bindings)
if isinstance(model, Template):
    _, graph = model.fill(BLDG)
else:
    graph = model

print(graph.serialize())
# Out:
# @prefix brick: <https://brickschema.org/schema/Brick#> .
#
# <urn:building/530> a brick:Fan_Coil_Unit ;
#     brick:feeds <urn:building/zone_c413df9c> ;
#     brick:hasPart <urn:building/chw_coil_640b4e5c>,
#         <urn:building/hw_coil_5f91f070> ;
#     brick:hasPoint <urn:building/:BuildingName_02:FCU530_EffOcc>,
#         <urn:building/:BuildingName_02:FCU530_OccClgSpt>,
#         <urn:building/:BuildingName_02:FCU530_OccCmd>,
#         <urn:building/:BuildingName_02:FCU530_OccHtgSpt>,
#         <urn:building/:BuildingName_02:FCU530_UnoccClgSpt>,
#         <urn:building/:BuildingName_02:FCU530_UnoccHtgSpt>,
#         <urn:building/supply_temp_0abdd5f3> .
#
# <urn:building/:BuildingName_02:FCU530_ChwVlvPos> a brick:Chilled_Water_Valve ;
#     brick:hasPoint <urn:building/chw_coil-position_d9d2e728> .
#
# <urn:building/:BuildingName_02:FCU530_EffOcc> a brick:Occupancy_Status .
#
# <urn:building/:BuildingName_02:FCU530_HwVlvPos> a brick:Hot_Water_Valve ;
#     brick:hasPoint <urn:building/hw_coil-position_cf362cf3> .
#
# <urn:building/:BuildingName_02:FCU530_OccClgSpt> a brick:Occupied_Cooling_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU530_OccCmd> a brick:Occupancy_Command .
#
# <urn:building/:BuildingName_02:FCU530_OccHtgSpt> a brick:Occupied_Heating_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU530_RoomTmp> a brick:Air_Temperature_Sensor .
#
# <urn:building/:BuildingName_02:FCU530_UnoccClgSpt> a brick:Unoccupied_Cooling_Temperature_Setpoint .
#
# <urn:building/:BuildingName_02:FCU530_UnoccHtgSpt> a brick:Unoccupied_Heating_Temperature_Setpoint .
#
# <urn:building/chw_coil-position_d9d2e728> a brick:Valve_Position_Command .
#
# <urn:building/chw_coil_640b4e5c> a brick:Cooling_Coil ;
#     brick:hasPart <urn:building/:BuildingName_02:FCU530_ChwVlvPos> .
#
# <urn:building/hw_coil-position_cf362cf3> a brick:Valve_Position_Command .
#
# <urn:building/hw_coil_5f91f070> a brick:Heating_Coil ;
#     brick:hasPart <urn:building/:BuildingName_02:FCU530_HwVlvPos> .
#
# <urn:building/room-relative_humidity_f8a6a61c> a brick:Relative_Humidity_Sensor .
#
# <urn:building/room_05463694> a brick:Space ;
#     brick:hasPoint <urn:building/:BuildingName_02:FCU530_RoomTmp>,
#         <urn:building/room-relative_humidity_f8a6a61c> .
#
# <urn:building/supply_temp_0abdd5f3> a brick:Supply_Air_Temperature_Sensor .
#
# <urn:building/zone_c413df9c> a brick:HVAC_Zone ;
#     brick:hasPart <urn:building/room_05463694> .
# /Users/heslinge/Repos/BuildingMotif/buildingmotif/dataclasses/template.py:372: UserWarning: Parameters "hw_coil, room-relative_humidity, zone, supply_temp, room, hw_coil-position, chw_coil-position, chw_coil" were not provided during evaluation
#   warnings.warn(
