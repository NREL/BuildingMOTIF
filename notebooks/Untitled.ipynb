# %%
from buildingmotif.dataclasses import Library
from buildingmotif import BuildingMOTIF
from buildingmotif.namespaces import BRICK, BACNET
from buildingmotif.template_finder.template_finder import calculate_template_cost
import pandas as pd

# %%
bm = BuildingMOTIF("sqlite://")
pointlist = Library.load(directory="../../libraries/pointlist-test")
tstat_template = pointlist.get_template_by_name("tstat")
tstat_template.inline_dependencies()

print(tstat_template.body.serialize(format="ttl"))
# Out:
# @prefix ns1: <http://data.ashrae.org/bacnet/2020#> .
# @prefix ns2: <https://brickschema.org/schema/Brick#> .
# @prefix ns3: <https://brickschema.org/schema/Brick/ref#> .
#
# <urn:___param___#name> a ns2:Thermostat ;
#     ns2:hasLocation <urn:___param___#zone> ;
#     ns2:hasPoint <urn:___param___#command>,
#         <urn:___param___#occ>,
#         <urn:___param___#sen>,
#         <urn:___param___#sp>,
#         <urn:___param___#status> .
#
# <urn:___param___#command> a ns2:Mode_Command ;
#     ns3:hasExternalReference [ ns1:object-identifier "urn:___param___#command_object" ;
#             ns1:objectOf <urn:___param___#BACnet_device> ] .
#
# <urn:___param___#occ> a ns2:Occupancy_Sensor ;
#     ns3:hasExternalReference [ ns1:object-identifier "urn:___param___#occ_object" ;
#             ns1:objectOf <urn:___param___#BACnet_device> ] .
#
# <urn:___param___#sen> a ns2:Zone_Air_Temperature_Sensor ;
#     ns3:hasExternalReference [ ns1:object-identifier "urn:___param___#sen_object" ;
#             ns1:objectOf <urn:___param___#BACnet_device> ] .
#
# <urn:___param___#sp> a ns2:Zone_Air_Temperature_Setpoint ;
#     ns3:hasExternalReference [ ns1:object-identifier "urn:___param___#sp_object" ;
#             ns1:objectOf <urn:___param___#BACnet_device> ] .
#
# <urn:___param___#status> a ns2:Mode_Status ;
#     ns3:hasExternalReference [ ns1:object-identifier "urn:___param___#status_object" ;
#             ns1:objectOf <urn:___param___#BACnet_device> ] .
#
# <urn:___param___#BACnet_device> a ns1:BACnetDevice .

# %%
tstat_param_classes = [
    BRICK.Thermostat, 
    BRICK.Zone_Air_Temperature_Setpoint, 
    BRICK.Occupancy_Sensor, 
    BRICK.Zone_Air_Temperature_Sensor, 
    BACNET.BACnetDevice, 
    BRICK.Mode_Status, 
    BRICK.Mode_Command,
]

# %%
# perfect match
cost = calculate_template_cost(tstat_param_classes, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status Mode_Command
# Zone_Air_Temperature_Sensor            inf         inf          inf
# Mode_Command                           inf         inf            1
# BACnetDevice                             1         inf          inf
# Zone_Air_Temperature_Setpoint          inf         inf          inf
# Thermostat                             inf         inf          inf
# Mode_Status                            inf           1          inf
# Occupancy_Sensor                       inf         inf          inf
#
# kept edges:
# Zone_Air_Temperature_Sensor <- 1 -> Zone_Air_Temperature_Sensor
# Mode_Command <- 1 -> Mode_Command
# BACnetDevice <- 1 -> BACnetDevice
# Zone_Air_Temperature_Setpoint <- 1 -> Zone_Air_Temperature_Setpoint
# Thermostat <- 1 -> Thermostat
# Mode_Status <- 1 -> Mode_Status
# Occupancy_Sensor <- 1 -> Occupancy_Sensor
#
# cost: {'edge_cost': 7, 'params_dropped': 0, 'tokens_dropped': 0}

# %%
# too specfic 
too_specfic = tstat_param_classes.copy()

too_specfic.remove(BRICK.Mode_Command)
too_specfic.append(BRICK.Automatic_Mode_Command)

cost = calculate_template_cost(too_specfic, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status Automatic_Mode_Command
# Zone_Air_Temperature_Sensor            inf         inf                    inf
# Mode_Command                           inf         inf                      2
# BACnetDevice                             1         inf                    inf
# Zone_Air_Temperature_Setpoint          inf         inf                    inf
# Thermostat                             inf         inf                    inf
# Mode_Status                            inf           1                    inf
# Occupancy_Sensor                       inf         inf                    inf
#
# kept edges:
# Zone_Air_Temperature_Sensor <- 1 -> Zone_Air_Temperature_Sensor
# Mode_Command <- 2 -> Automatic_Mode_Command
# BACnetDevice <- 1 -> BACnetDevice
# Zone_Air_Temperature_Setpoint <- 1 -> Zone_Air_Temperature_Setpoint
# Thermostat <- 1 -> Thermostat
# Mode_Status <- 1 -> Mode_Status
# Occupancy_Sensor <- 1 -> Occupancy_Sensor
#
# cost: {'edge_cost': 8, 'params_dropped': 0, 'tokens_dropped': 0}

# %%
# too vague 
too_vague = tstat_param_classes.copy()

too_vague.remove(BRICK.Mode_Command)
too_vague.append(BRICK.Command)

cost = calculate_template_cost(too_vague, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status Command
# Zone_Air_Temperature_Sensor            inf         inf     inf
# Mode_Command                           inf         inf     inf
# BACnetDevice                             1         inf     inf
# Zone_Air_Temperature_Setpoint          inf         inf     inf
# Thermostat                             inf         inf     inf
# Mode_Status                            inf           1     inf
# Occupancy_Sensor                       inf         inf     inf
#
# cost: inf

# %%
# bad param 
bad_param = tstat_param_classes.copy()

bad_param.remove(BRICK.Mode_Command)
bad_param.append(BRICK.Mode_Status)

cost = calculate_template_cost(bad_param, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status Mode_Status
# Zone_Air_Temperature_Sensor            inf         NaN         NaN
# Mode_Command                           inf         NaN         NaN
# BACnetDevice                             1         NaN         NaN
# Zone_Air_Temperature_Setpoint          inf         NaN         NaN
# Thermostat                             inf         NaN         NaN
# Mode_Status                            inf           1           1
# Occupancy_Sensor                       inf         NaN         NaN
#
# cost: inf

# %%
# missing param / extra token
missing_param = tstat_param_classes.copy()

missing_param.append(BRICK.Command)

cost = calculate_template_cost(missing_param, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status Mode_Command Command
# Zone_Air_Temperature_Sensor            inf         inf          inf     inf
# Mode_Command                           inf         inf            1     inf
# BACnetDevice                             1         inf          inf     inf
# Zone_Air_Temperature_Setpoint          inf         inf          inf     inf
# Thermostat                             inf         inf          inf     inf
# Mode_Status                            inf           1          inf     inf
# Occupancy_Sensor                       inf         inf          inf     inf
#
# kept edges:
# Zone_Air_Temperature_Sensor <- 1 -> Zone_Air_Temperature_Sensor
# Mode_Command <- 1 -> Mode_Command
# BACnetDevice <- 1 -> BACnetDevice
# Zone_Air_Temperature_Setpoint <- 1 -> Zone_Air_Temperature_Setpoint
# Thermostat <- 1 -> Thermostat
# Mode_Status <- 1 -> Mode_Status
# Occupancy_Sensor <- 1 -> Occupancy_Sensor
#
# cost: {'edge_cost': 7, 'params_dropped': 0, 'tokens_dropped': 1}

# %%
# extra param / missing token
extra_param = tstat_param_classes.copy()

extra_param.remove(BRICK.Mode_Command)

cost = calculate_template_cost(extra_param, tstat_template)

print("\ncost:", cost)
# Out:
# cost matrix:
#                               Thermostat Zone_Air_Temperature_Setpoint  \
# Zone_Air_Temperature_Sensor          inf                           inf
# Mode_Command                         inf                           inf
# BACnetDevice                         inf                           inf
# Zone_Air_Temperature_Setpoint        inf                             1
# Thermostat                             1                           inf
# Mode_Status                          inf                           inf
# Occupancy_Sensor                     inf                           inf
#
#                               Occupancy_Sensor Zone_Air_Temperature_Sensor  \
# Zone_Air_Temperature_Sensor                inf                           1
# Mode_Command                               inf                         inf
# BACnetDevice                               inf                         inf
# Zone_Air_Temperature_Setpoint              inf                         inf
# Thermostat                                 inf                         inf
# Mode_Status                                inf                         inf
# Occupancy_Sensor                             1                         inf
#
#                               BACnetDevice Mode_Status
# Zone_Air_Temperature_Sensor            inf         inf
# Mode_Command                           inf         inf
# BACnetDevice                             1         inf
# Zone_Air_Temperature_Setpoint          inf         inf
# Thermostat                             inf         inf
# Mode_Status                            inf           1
# Occupancy_Sensor                       inf         inf
#
# kept edges:
# Zone_Air_Temperature_Sensor <- 1 -> Zone_Air_Temperature_Sensor
# BACnetDevice <- 1 -> BACnetDevice
# Zone_Air_Temperature_Setpoint <- 1 -> Zone_Air_Temperature_Setpoint
# Thermostat <- 1 -> Thermostat
# Mode_Status <- 1 -> Mode_Status
# Occupancy_Sensor <- 1 -> Occupancy_Sensor
#
# cost: {'edge_cost': 6, 'params_dropped': 1, 'tokens_dropped': 0}
